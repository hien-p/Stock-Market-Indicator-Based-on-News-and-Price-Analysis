# %% [markdown]
# #Params

# %%
DATA_SOURCE: str = 'https://github.com/h4438/data/raw/master/daily_articles.csv'
DATA_TYPE: str = 'csv'
MODEL_NAME: str = 'bert-base-multilingual-cased'
GDRIVE_PATH: str = 'gdrive/MyDrive/models/'

# %% [markdown]
# #Import

# %%
# https://stackoverflow.com/questions/39142778/how-to-determine-the-language-of-a-piece-of-text
# https://www.geeksforgeeks.org/how-to-count-occurrences-of-specific-value-in-pandas-column/
# https://www.geeksforgeeks.org/python-sentiment-analysis-using-vader/

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 38.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 80.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.0 tokenizers-0.13.2 transformers-4.26.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import time
from tqdm.auto import tqdm
from sklearn.metrics import classification_report,confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
from transformers import BertTokenizer
import os
from google.colab import drive, files

# %% [markdown]
# ##bert process

# %%
class BERT_Classifier:
  
  MODELS = {'bert-base-multilingual-cased':'vnnews_multi_bert'}
  
  def __init__(self, nlabels = 3):
    print("Classifier is ready")
    self.nlabels = nlabels
    return

  def DatasetMapFunction(self, input_ids, attn_masks, labels):
    # define the output of the whole
    return {
        'input_ids':input_ids,
        'attention_mask':attn_masks},labels

  def load_model_tokenizer(self, MODEL_NAME):
    self.tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)
    bert_path = GDRIVE_PATH+BERT_Classifier.MODELS[MODEL_NAME]
    self.bert = tf.keras.models.load_model(bert_path)
    return

  def tokenize_data(self, data,max_len=256):
    ids = np.zeros((len(data),max_len))
    masks = np.zeros((len(data),max_len))
    for i, text in tqdm(enumerate(data)):
      tokenized_text = self.tokenizer.encode_plus(
          text,
          max_length=max_len,
          truncation=True,
          padding='max_length',
          add_special_tokens=True,
          return_tensors='tf'
      )
      ids[i,:] = tokenized_text.input_ids
      masks[i,:] = tokenized_text.attention_mask
    return ids, masks


  def label_news(self, text_data):
    # input
    text = text_data
    # tokenize
    x_input_ids, x_attn_masks = self.tokenize_data(text)
    # one hot
    labels = np.zeros((len(text),self.nlabels))
    # create dataset
    dataset = tf.data.Dataset.from_tensor_slices(
      (x_input_ids, x_attn_masks, labels))
    # change format
    dataset = dataset.map(self.DatasetMapFunction)
    text_ds = dataset.batch(1)
    pred_raw = self.bert.predict(text_ds)
    pred = np.argmax(pred_raw, axis=1)
    pred = pred+1 # due to index transition
    return text,dataset,pred

# %% [markdown]
# ##data process

# %%
class News_Process:
  def __init__(self):
    print("Ready to process news")
    self.origin_df = None
    self.origin_langs = None
    return
  
  def read_news(self, src = DATA_SOURCE, type = DATA_TYPE):
    if DATA_TYPE == 'csv':
      self.origin_df = pd.read_csv(src)
    else:
      self.origin_df = pd.read_excel(src)
    return self.origin_df

  def visualize_news(self):
    ntc = "\n--->"
    print(self.origin_df.head(5))
    print(f'{ntc}Data shape',self.origin_df.shape)
    print(f'{ntc}Unique values of each column')
    print(self.origin_df.nunique())
    print(f'{ntc}Nan values of each column')
    print(self.origin_df.isna().sum())
    return
    
  def handle_nan_of(self, target_col, value):
    self.origin_df[target_col]=self.origin_df[target_col].fillna(value)
    return

  def lower_case(self, target_col = ['title']):
    for col in target_col:
      self.origin_df[col]=self.origin_df[col].str.lower()
    return

  def remove_non_ascii(self, target_col = ['title']):
    for col in target_col:
      self.origin_df[col]=\
      self.origin_df[col].str.encode('ascii','ignore').str.decode('ascii')
    return

  def combine_text(self, target_col, out_col='combine'):
    data = self.origin_df[target_col[0]]
    for col in target_col[1:]:
      data += (" "+self.origin_df[col])
    self.origin_df[out_col] = data
    return

  def drill_down(self,target_col):
    res = self.origin_df[target_col].value_counts()
    print(res)
    return 
  
  def get_df(self):
    return self.origin_df

  def set_df(self, df):
    self.origin_df = df
    return

  def add_column(self,data,name):
    self.origin_df[name] = data
    return

# %%
df = pd.Series(['m©ª«zy', '¤¥uw', 'ÆÇva%l 672'])
d= df.str.encode('ascii', 'ignore').str.decode('ascii')
print("After removing non-ascii:")
print(d)
# Out:
# After removing non-ascii:
# 0         mzy
# 1          uw
# 2    va%l 672
# dtype: object

# %% [markdown]
# ##load from GDrive

# %%
drive.mount("gdrive")
# Out:
# Mounted at gdrive

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# #Data

# %%
txt_new = ['title','description']
news_ps = News_Process()
news_ps.read_news()
news_ps.lower_case(txt_new)
news_ps.visualize_news()
# Out:
# Ready to process news
#          date                                              title  \
# 0  2023-01-18                người dùng chuộng thanh toán online
# 1  2023-01-23  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...
# 2  2023-01-13  vietnam international commercialbank : payment...
# 3  2023-01-12  vn-index continues sideways - vnexpress intern...
# 4  2023-01-12  nhiều hoạt động tương tác và quà tặng tại momo...
#
#                                          description stock_group
# 0  nhiều người chọn mua sắm, thanh toán với thẻ t...         VIB
# 1  thẻ vib travel elite giúp tích lũy dặm thưởng,...         VIB
# 2  (marketscreener.com) \n \n vietnam internation...         VIB
# 3  vietnam’s benchmark vn-index rose 0.06% to 1,0...         VIB
# 4  thông qua lắc xì 2023 với nhiều quà tặng giá t...         VIB
#
# --->Data shape (1781, 4)
#
# --->Unique values of each column
# date            33
# title          523
# description    529
# stock_group     33
# dtype: int64
#
# --->Nan values of each column
# date           0
# title          0
# description    6
# stock_group    0
# dtype: int64

# %%
news_ps.handle_nan_of('description',"")
news_ps.combine_text(txt_new)
news_ps.visualize_news()
in_data = news_ps.get_df()
# Out:
#          date                                              title  \
# 0  2023-01-18  người dùng chuộng thanh toán online nhiều ngườ...
# 1  2023-01-23  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...
# 2  2023-01-13  vietnam international commercialbank : payment...
# 3  2023-01-12  vn-index continues sideways - vnexpress intern...
# 4  2023-01-12  nhiều hoạt động tương tác và quà tặng tại momo...
#
#                                          description stock_group  \
# 0  nhiều người chọn mua sắm, thanh toán với thẻ t...         VIB
# 1  thẻ vib travel elite giúp tích lũy dặm thưởng,...         VIB
# 2  (marketscreener.com) \n \n vietnam internation...         VIB
# 3  vietnam’s benchmark vn-index rose 0.06% to 1,0...         VIB
# 4  thông qua lắc xì 2023 với nhiều quà tặng giá t...         VIB
#
#                                              combine
# 0  người dùng chuộng thanh toán online nhiều ngườ...
# 1  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...
# 2  vietnam international commercialbank : payment...
# 3  vn-index continues sideways - vnexpress intern...
# 4  nhiều hoạt động tương tác và quà tặng tại momo...
#
# --->Data shape (1781, 5)
#
# --->Unique values of each column
# date            33
# title          552
# description    530
# stock_group     33
# combine        552
# dtype: int64
#
# --->Nan values of each column
# date           0
# title          0
# description    0
# stock_group    0
# combine        0
# dtype: int64

# %% [markdown]
# #Model

# %%
my_bert = BERT_Classifier()
my_bert.load_model_tokenizer(MODEL_NAME)
# Out:
# Classifier is ready
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %%
sample = in_data.iloc[:10,:]
print(sample.shape)
print(in_data.shape)
print(in_data.head())
# Out:
# (10, 5)
# (1781, 5)
#          date                                              title  \
# 0  2023-01-18  người dùng chuộng thanh toán online nhiều ngườ...
# 1  2023-01-23  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...
# 2  2023-01-13  vietnam international commercialbank : payment...
# 3  2023-01-12  vn-index continues sideways - vnexpress intern...
# 4  2023-01-12  nhiều hoạt động tương tác và quà tặng tại momo...
#
#                                          description stock_group  \
# 0  nhiều người chọn mua sắm, thanh toán với thẻ t...         VIB
# 1  thẻ vib travel elite giúp tích lũy dặm thưởng,...         VIB
# 2  (marketscreener.com) \n \n vietnam internation...         VIB
# 3  vietnam’s benchmark vn-index rose 0.06% to 1,0...         VIB
# 4  thông qua lắc xì 2023 với nhiều quà tặng giá t...         VIB
#
#                                              combine
# 0  người dùng chuộng thanh toán online nhiều ngườ...
# 1  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...
# 2  vietnam international commercialbank : payment...
# 3  vn-index continues sideways - vnexpress intern...
# 4  nhiều hoạt động tương tác và quà tặng tại momo...

# %%
in_data.iloc[240,:]
# Out:
# date                                                  2023-01-10
# title          philippines sea exploration deal with beijing,...
# description
# stock_group                                                  BID
# combine        philippines sea exploration deal with beijing,...
# Name: 240, dtype: object

# %%
origin_news, dataset, labels = my_bert.label_news(in_data['title'])
# Out:
# 0it [00:00, ?it/s]
# 1781/1781 [==============================] - 2043s 1s/step

# %%
a = [print(f'{text[:110]}...:{pds}') for text,pds in zip(origin_news,labels)]
b = 1
# Out:
# người dùng chuộng thanh toán online nhiều người chọn mua sắm, thanh toán với thẻ tín dụng vib để hưởng bộ ba ư...:2
# thẻ tín dụng vib travel elite nhiều ưu đãi dịp tết thẻ vib travel elite giúp tích lũy dặm thưởng, đặc quyền ph...:3
# vietnam international commercialbank : payment instruction for deposit book having due date during tet holiday...:2
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# nhiều hoạt động tương tác và quà tặng tại momo lắc xì 2023 thông qua lắc xì 2023 với nhiều quà tặng giá trị, m...:2
# bustling m&a deals in banking industry at year beginning right from the beginning of 2023, many banks have ann...:2
# banks plan to pay cash dividends for first time in three years some banks have announced plans to pay cash div...:3
# người dùng chuộng thanh toán online nhiều người chọn mua sắm, thanh toán với thẻ tín dụng vib để hưởng bộ ba ư...:2
# thẻ tín dụng vib travel elite nhiều ưu đãi dịp tết thẻ vib travel elite giúp tích lũy dặm thưởng, đặc quyền ph...:3
# vietnam international commercialbank : payment instruction for deposit book having due date during tet holiday...:2
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# nhiều hoạt động tương tác và quà tặng tại momo lắc xì 2023 thông qua lắc xì 2023 với nhiều quà tặng giá trị, m...:2
# bustling m&a deals in banking industry at year beginning right from the beginning of 2023, many banks have ann...:2
# banks plan to pay cash dividends for first time in three years some banks have announced plans to pay cash div...:3
# dollar drops on black market - vnexpress international the u.s. dollar dropped slightly against the dong on th...:2
# dollar continues to rise on black market - vnexpress international the u.s. dollar gained marginally against t...:3
# dollar slips on black market - vnexpress international the u.s. dollar fell marginally on the black market but...:2
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# vn-index hits 6-week high - vnexpress international vietnam’s benchmark vn-index rose 0.61% to 1066.68 points ...:3
# dollar increases slightly on black market - vnexpress international the u.s. dollar rose slightly against the ...:3
# dollar gains on black market - vnexpress international the u.s. dollar surged against the vietnamese dong wedn...:3
# dollar declines on black market - vnexpress international the u.s. dollar dropped 0.04% to vnd23,540 at unoffi...:3
# dollar inches up against dong - vnexpress international the u.s. dollar gained marginally against the vietname...:3
# sun life financial, inc. (slf) q4 2022 earnings call transcript sun life financial, inc. (nyse:nyse:slf) q4 20...:2
# bustling m&a deals in banking industry at year beginning right from the beginning of 2023, many banks have ann...:2
# banks plan to pay cash dividends for first time in three years some banks have announced plans to pay cash div...:3
# người dùng chuộng thanh toán online nhiều người chọn mua sắm, thanh toán với thẻ tín dụng vib để hưởng bộ ba ư...:2
# thẻ tín dụng vib travel elite nhiều ưu đãi dịp tết thẻ vib travel elite giúp tích lũy dặm thưởng, đặc quyền ph...:3
# vietnam international commercialbank : payment instruction for deposit book having due date during tet holiday...:2
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# nhiều hoạt động tương tác và quà tặng tại momo lắc xì 2023 thông qua lắc xì 2023 với nhiều quà tặng giá trị, m...:2
# bustling m&a deals in banking industry at year beginning right from the beginning of 2023, many banks have ann...:2
# banks plan to pay cash dividends for first time in three years some banks have announced plans to pay cash div...:3
# dollar drops on black market - vnexpress international the u.s. dollar dropped slightly against the dong on th...:2
# dollar continues to rise on black market - vnexpress international the u.s. dollar gained marginally against t...:3
# dollar slips on black market - vnexpress international the u.s. dollar fell marginally on the black market but...:2
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# vn-index hits 6-week high - vnexpress international vietnam’s benchmark vn-index rose 0.61% to 1066.68 points ...:3
# dollar increases slightly on black market - vnexpress international the u.s. dollar rose slightly against the ...:3
# dollar gains on black market - vnexpress international the u.s. dollar surged against the vietnamese dong wedn...:3
# dollar declines on black market - vnexpress international the u.s. dollar dropped 0.04% to vnd23,540 at unoffi...:3
# dollar inches up against dong - vnexpress international the u.s. dollar gained marginally against the vietname...:3
# sun life financial, inc. (slf) q4 2022 earnings call transcript sun life financial, inc. (nyse:nyse:slf) q4 20...:2
# bustling m&a deals in banking industry at year beginning right from the beginning of 2023, many banks have ann...:2
# banks plan to pay cash dividends for first time in three years some banks have announced plans to pay cash div...:3
# afc on the road - vietnam vietnam is the key beneficiary in asia of shifting supply chains. tourism should mak...:2
# những công nhân xa quê trên chuyến bay đoàn viên chuyến bay của vietnam airlines cất cánh hôm 9/1 đưa hàng tră...:2
# gỗ trường thành vào top 500 doanh nghiệp tư nhân lớn nhất việt nam tập đoàn kỹ nghệ gỗ trường thành (ttf) vào ...:2
# dấu ấn của kinh tế tư nhân trong lĩnh vực hạ tầng nhiều doanh nghiệp tư nhân để lại dấu ấn ở những lĩnh vực mà...:2
# boe - nhà cung ứng của apple và samsung muốn xây nhà máy ở việt nam đối tác cung ứng màn hình cho cả 2 gã khổn...:2
# ban mai - cô bé mắc chứng khó đọc thành hoa hậu ban mai từng là cô bé mắc chứng khó đọc, vươn lên thành sinh v...:2
# deaths on location: how the ‘twilight zone’ and ‘midnight rider’ tragedies may influence ‘rust’ prosecution on...:2
# cổ phiếu hòa phát hút tiền nhà đầu tư ngoại giá chạm đáy hai năm trong khi triển vọng tăng trưởng dài hạn tích...:3
# h'hen niê: 'tôi trải qua một năm kỳ diệu' hoa hậu h'hen niê nói có một năm hoạt động tích cực, thử sức với vai...:2
# táo quân 2023: tiếng cười nhẹ nhàng chương trình táo quân 2023 giảm tính đả kích, tạo tiếng cười nhẹ nhàng khi...:1
# mai ngô giúp mẹ bán hoa tết tp hcm- á hậu mai ngô cùng em gái phụ mẹ bán hoa những ngày giáp tết quý mão. tp h...:1
# deaths on location: how the ‘twilight zone’ and ‘midnight rider’ tragedies may influence ‘rust’ prosecution on...:2
# bamboo airways và baa training vietnam hợp tác đào tạo phi công mpl chương trình dự kiến đào tạo 100 học viên ...:2
# hàng không năm 2022 - bay nhiều vẫn lỗ du lịch phục hồi nhưng năm 2022, vietnam airlines, vietjet vẫn chịu nhi...:3
# uscirf tiếp tục kêu gọi trả tự do cho ông nguyễn bắc truyển ủy ban tự do tôn giáo quốc tế của hoa kỳ (uscirf) ...:1
# đạo đức trong influencer marketing: minh bạch trong thông tin tài trợ là yếu tố quan trọng nhất trong nhiều nă...:2
# khách mời bàn về thăng trầm của điện ảnh việt charlie nguyễn, bình bồng bột... cùng các khách mời bàn về thăng...:2
# khách mời vietnam cinema bàn về thăng trầm của điện ảnh việt charlie nguyễn, bình bồng bột... cùng các khách m...:2
# sacombank nhận hai giải thưởng về thương hiệu sacombank nhận giải thưởng thương hiệu vàng tp hcm năm 2022 và t...:2
# đại sứ anh iain frew: 'tôi hoà mình vào truyền thống tết của việt nam' đại sứ anh gửi lời chúc mừng năm mới bằ...:2
# biển đông có yên tĩnh không? khi giới thiệu thư chúc tết của ông tập cận bình gửi ông trọng với thiên hạ, trun...:2
# [qc] thực hư lời đồn robot hút bụi “toàn năng, đột phá” của 2 siêu phẩm nhà ecovacs tích hợp thêm nhiều chức n...:2
# bảy nỗi sợ tôi vừa tiễn một đoàn khách pháp 10 người, đi du thuyền hạ long tham quan hai ngày một đêm. tôi vừa...:2
# 7 nỗi sợ của du khách tôi vừa tiễn một đoàn khách pháp 10 người, đi du thuyền hạ long tham quan hai ngày một đ...:2
# ngọc châu catwalk kiểu 'hoa sen' ở bán kết miss universe mỹ- người đẹp diện đầm dạ hội của chung thanh phong, ...:2
# các nhà báo mỹ và vn nói gì về lối làm truyền thông của vinfast? kevin williams nói với bbc news tiếng việt v...:2
# vụ nữ sinh huflit: cần minh bạch thông tin thay vì đòi xử lý người đưa tin! trường quân sự quân khu 7 bác bỏ t...:2
# nhiều hoạt động tương tác và quà tặng tại momo lắc xì 2023 thông qua lắc xì 2023 với nhiều quà tặng giá trị, m...:2
# học cách đặt câu hỏi sang tuổi 22, tôi bắt đầu học tiếng đức, như vậy là hơi muộn để bắt đầu. nhưng tôi tin rằ...:2
# nashtech mở văn phòng mới tại đà nẵng nashtech khai trương văn phòng mới tại đà nẵng hôm 13/11, tại tầng 19, t...:2
# việt nam sẽ là câu chuyện kinh tế thú vị nhất năm 2023 việt nam đang ngày càng nhận được sự quan tâm của toàn ...:2
# hoa hậu ngọc châu phủ nhận khai gian bằng cấp hoa hậu ngọc châu, 28 tuổi, xác nhận chưa tốt nghiệp đại học tôn...:2
# 'nhà bà nữ doanh thu cao nhưng không bứt phá chất lượng' không thể chỉ dựa vào doanh thu thì có thể kết luận p...:2
# khả năng huỷ niêm yết cổ phiếu vietnam airlines ngày 2/2, sở giao dịch chứng khoán tp.hcm đã có thông báo gửi ...:2
# tập đoàn đông dương đặt mục tiêu mở rộng 300 cửa hàng toàn quốc doanh nghiệp hướng đến tạo dựng hệ sinh thái c...:2
# nhiều cơ hội đặt phòng khách sạn và tour chơi tết giờ chót sức mua năm nay thấp nên hiện khách sạn hoặc tour c...:2
# nhiều cơ hội đặt khách sạn và tour chơi tết giờ chót sức mua năm nay thấp nên hiện khách sạn hoặc tour cho mùn...:2
# degaussing system market worth $740 million by 2027 - exclusive report by marketsandmarkets™ the degaussing sy...:3
# degaussing system market worth $740 million by 2027 - exclusive report by marketsandmarkets™ chicago, jan. 16,...:3
# bí quyết chạy ultra của runner đà nẵng đà nẵng- bận rộn với con nhỏ, công việc ở xa nhà, nhưng nguyễn minh tuấ...:2
# burt bacharach, the essence of pop music success, dies at 94 seen by some as his generation's greatest songwri...:2
# burt bacharach, the essence of pop music success, dies at 94 los angeles — at the brill building, the legendar...:2
# runner cả nước sẵn sàng cho giải chạy đêm tp hcm 10.000 vđv, trong đó có những tên tuổi hàng đầu sẽ có mặt tại...:2
# runner sẵn sàng cho giải chạy đêm tp hcm 10.000 vđv, trong đó có những tên tuổi hàng đầu, sẽ có mặt tại tp hcm...:2
# runner đổ về tp hcm dự giải chạy đêm 10.000 vđv, trong đó có những tên tuổi hàng đầu sẽ có mặt tại tp hcm vào ...:2
# cơ hội thoát vùng an toàn, thử thách bản thân tại unilever chị minh nguyệt - giám đốc kênh hiện đại và thương ...:2
# hoa hậu mai phương xin lỗi khán giả hoa hậu mai phương, 23 tuổi, xin lỗi khán giả vì bị nhiều người chỉ trích ...:2
# mv của trọng hiếu vào chung kết eurovision song contest đức "dare to be different" của trọng hiếu là một trong...:2
# vietinbank lì xì khách hàng đầu xuân ngân hàng dành tặng lì xì bằng tiền mặt cùng hàng nghìn combo tài lộc cho...:2
# người dùng chuộng thanh toán online nhiều người chọn mua sắm, thanh toán với thẻ tín dụng vib để hưởng bộ ba ư...:2
# 30 sff titles to look forward to in 2023 i’m calling it first sentence euphoria. it’s that feeling you get whe...:2
# võ hoàng yến hội ngộ bạn trai ở mỹ người mẫu võ hoàng yến du lịch, mua sắm, dành thời gian bên bạn trai tại mỹ...:2
# h'hen niê: 'tôi không còn khóc khi bị chê' hoa hậu h'hen niê nói hiện trưởng thành, đối mặt mọi thứ với tâm lý...:2
# h'hen niê: 'tôi không còn khóc một mình khi bị chê' hoa hậu h'hen niê nói hiện trưởng thành, đối mặt mọi thứ v...:2
# chấp thuận cho việt nam cử 20 đội tham gia vex robotics hà nội (sputnik) - việt nam được cử 20 đội chơi tham g...:2
# aeon mall bình tân hoàn tất cải tạo trước thềm năm mới ngoài mở 24 gian hàng mới, aeon mall bình tân hoàn tất ...:2
# mặt số đồng hồ có bản đồ việt nam lập kỷ lục lần đầu tiên mặt số đồng hồ tráng men cloisonné tạo hình bản đồ v...:2
# đồng hồ lập kỷ lục có chi tiết bản đồ việt nam nhỏ nhất lần đầu tiên mặt số đồng hồ tráng men cloisonné tạo hì...:2
# how zimbabwe's pangolins are being given a second chance... [263chat] zimbabwe's wildlife landscape is endowed...:2
# 'du lịch việt nam có đủ yếu tố để vượt qua thái lan' ngành du lịch việt nam trong hơn một thập kỷ qua đã ghi n...:2
# remembering burt bacharach burt bacharach, who is among the musical giants of our era, passed away at the age ...:2
# hàn quốc lần đầu tiên thừa nhận tội ác của binh lính hàn đã gây ra tại việt nam tuần này, chúng...:2
# vietnam airlines nối thêm đường bay đến trung quốc trong hai tháng tới, 9/10 chặng bay đến trung quốc - thị tr...:2
# top 11 chiến lược marketing ngành fmcg năm 2023 - cleverads chiến lược marketing ngành fmcg là gì? nó đem lại ...:2
# thẻ tín dụng vib travel elite nhiều ưu đãi dịp tết thẻ vib travel elite giúp tích lũy dặm thưởng, đặc quyền ph...:3
# lương nhân sự trung cao cấp khả năng tăng 5-25% năm nay khảo sát của một số hãng tuyển dụng cho biết lao động ...:3
# tân uỷ ban việt nam ở quốc hội mỹ cam kết thúc đẩy nhân quyền bốn lãnh đạo mới của uỷ ban việt nam (vietnam ca...:2
# gia tăng xuất khẩu lao động và cải thiện thứ hạng về tệ nạn... ‘buôn người’ (p3) báo cáo tip 2022 cho thấy cộn...:2
# lần đầu tiên học sinh việt dự giải đấu robotics lớn nhất thế giới 20 đội thi của học sinh việt nam sẽ tranh tà...:2
# lần đầu tiên học sinh việt dự giải vô địch robotics lớn nhất thế giới lần đầu tiên, 20 đội thi của học sinh vi...:2
# vn-index secures 8-session winning streak - vnexpress international vietnam’s benchmark vn-index rose 0.81 per...:3
# chính sách đối ngoại của việt nam sẽ nghiêng về phía nào? tuần này, trên báo chí nga và nước ngoài có...:2
# đại sứ hoa kỳ gửi thiệp chúc tết tới trẻ khiếm thị đại sứ hoa kỳ marc knapper và phu nhân mới làm thiệp chữ nổ...:2
# nhu cầu về các sản phẩm "made in vietnam" đang chậm lại vinacapital cho rằng, tăng trưởng gdp của việt nam sẽ ...:1
# gia tăng xuất khẩu lao động và cải thiện thứ hạng về tệ nạn... ‘buôn người’ (p2) ngoài việt nam còn có campuch...:1
# xu hướng marketing “neo giữ” ký ức: khi người tiêu dùng có xu hướng tìm về những giá trị tích cực trong quá kh...:2
# sống trong nhà thông minh hà nội- thiết bị thông minh cho phép anh minh điều khiển mọi thứ trong nhà từ bật cô...:2
# đảng cộng sản việt nam tròn 93 tuổi và tầm nhìn 2045 từ các phía một số thách thức cho đảng cộng sản việt...:2
# việt nam treo thưởng 1 triệu đô cho huy chương vàng olympic mỗi vận động viên việt nam giành được huy chương v...:3
# ứng dụng content marketing vào quá trình ứng tuyển: bí quyết tăng khả năng nhận việc trong thị trường cạnh tra...:2
# baldwin, brandon lee, fantozzi: quando il cinema diventa un reato non solo "rust": la storia del cinema è pien...:2
# partial validation of a taqman quantitative polymerase chain reaction for the detection of the three genotypes...:2
# om duimen en vingers bij af te likken: deze 23 culinaire nieuwkomers verdienen in 2023 een plek op uw radar be...:2
# 2023 – năm của ‘vận mệnh tương quan’? việt nam cũng đề cập đến sự kiện ông tập cận bình và ông nguyễn phú trọn...:2
# lần đầu tiên little saigon có phố hoa ngày tết lần đầu tiên cộng đồng người việt ở mỹ dựng phố hoa vào ngày tế...:2
# 5 xu hướng marketing trong năm 2023: trải nghiệm người dùng là ưu tiên hàng đầu sự thay đổi liên tục trong hàn...:2
# đồng yen mất giá kỷ lục, fpt việt nam vẫn thắng lớn tập đoàn công nghệ việt nam fpt vượt sóng gió ở thị trường...:1
# thiết kế việt thăng hoa trên trường quốc tế các thiết kế việt ngày càng được nhiều ngôi sao và khách nước ngoà...:2
# ‘hồng phúc’ từ những... ‘chị’... trang, ‘anh’ triết,... dẫu cha, chú của các “anh”, các “chị” như “anh” triết,...:2
# nửa thế kỷ cải tạo làm cạn kiệt tài nguyên một đbscl đang chết dần kế hoạch phát triển nào thì cũng phải tính ...:2
# vietnam attends fifth international conference for world balance a vietnamese delegation led by deputy head of...:2
# afc on the road - vietnam vietnam is the key beneficiary in asia of shifting supply chains. tourism should mak...:2
# fm: wagons east as the frontier beckons ishares msci frontier and select em etf (fm) tracks an index of fronti...:2
# cổ phiếu hòa phát hút tiền nhà đầu tư ngoại giá chạm đáy hai năm trong khi triển vọng tăng trưởng dài hạn tích...:3
# hoa phat : supplied 402,000 tons of steel in january (marketscreener.com)
#  in january 2023, hoa phat group pr...:3
# vn-index hits 6-week high - vnexpress international vietnam’s benchmark vn-index rose 0.61% to 1066.68 points ...:3
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# vn-index secures 8-session winning streak - vnexpress international vietnam’s benchmark vn-index rose 0.81 per...:3
# steel makers witness hardships in q4/2022 steel companies witnessed hardships in the fourth quarter of 2022 wi...:2
# gop’s hung cao mulls u.s. senate bid in virginia hung cao, who ran for congress in northern virginia last year...:2
# as southeast asia emerges as a capital markets contender, vietnam primes growing digital companies for global ...:2
# can he make case for 4 more years? washington (ap) — this should be a high point of joe biden's presidency. he...:2
# analysis: can biden make his case for four more years? joe biden's state of the union address comes at a cruci...:2
# analysis: can biden make his case for four more years? washington (ap) — this should be a high point of joe bi...:2
# analysis: can biden make his case for four more years? washington (ap) — this should be a high point of joe bi...:2
# mauritius: india-mauritius relations - has it always been "willing subordination"? [l'express] diplomats and a...:2
# analysis: can biden make his case for four more years? joe biden's state of the union address comes at a cruci...:2
# a tale of three cities. u.s. hypocrisy and joe biden’s “rules based international order”. philip giraldi all g...:2
# an anti-graft drive brings down vietnam’s president the crackdown on corruption is also a serious reform effor...:2
# victor navasky, campaign manager john nichols
#
# one of the former nation editor and publisher’s greatest escapa...:2
# douglas macarthur (1880) macarthur is a major figure in us military and diplomatic history. he commanded a bri...:2
# thais gain edge in fight for asean crown two away goals in the first leg of the aff mitsubishi electric cup 20...:2
# thai enterprises spend more on software amid growing digitalisation the majority of software spending in thail...:2
# new superintendent tony watlington is here to transform philly schools tony watlington wasn’t naive. he knew a...:2
# thailand get vital away goals in hanoi hanoi: two away goals ensure thailand hold a slender advantage in their...:3
# the pacific pact is a boon for britain, and a big threat to eu trade supremacy the pacific pact is a boon for ...:2
# pedophile pop star gary glitter released from jail after serving half his sentence the disgraced english pop s...:2
# this is “the mule” – the us military’s pint-sized 4×4 officially named the “m274 truck platform utility 1⁄2 to...:2
# what’s up with… bt and azure, telecom italia, ofcom and openreach azure is the destination for bt’s latest mig...:2
# new bidding launched to find long thanh airport builder the investor of the long thanh airport project has lau...:2
# how the words candidates use affect their campaigns was the pennsylvania senate race decided by...vegetables? ...:2
# how to grow an app to 7-figures by app marketing by app masters steve's been kidnapped!
# and his ransom is $1...:2
# investment bank arc group acquires scandinavian management consultancy asia perspective in bid to solidify pos...:2
# shocking truth about anthony albanese's selfie with dan andrews billionaire trucking boss lindsay fox hosted a...:2
# ap photographer jack smith, who shot mount st. helens, dies jack smith, an associated press photographer who c...:2
# investment bank arc group acquires scandinavian management consultancy asia perspective in bid to solidify pos...:2
# ap photographer jack smith, who shot mount st. helens, dies seattle (ap) — jack smith, an associated press pho...:2
# tata group makes bid to become india’s first domestic iphone manufacturer tata group, india’s largest multinat...:2
# martin luther king jr.: q&a with ‘king: a life’ author jonathan eig on civil rights leader’s year in chicago k...:2
# robert downey jr displays his ripped abs and dons a curly wig to film new show the sympathizer he switched to ...:2
# philippines' marcos says south china sea 'keeps him up at night' davos, switzerland (afp) jan 18, 2023
#
#
#  phil...:2
# indonesia’s asean chairmanship: promoting asean relevance in 2023? the country takes up the bloc's rotating ch...:2
# from davos: mutiny on the mountain - politico - politico <ol><li>from davos: mutiny on the mountain - politico...:2
# the extraordinary benefits of a house made of mud mud, a traditional construction material in africa, more eas...:2
# bail for alleged nickel trading scammer ng yu zhi raised to $6 million this is a record sum, according to some...:2
# will suga yoshihide make a comeback? as prime minister kishida fights flagging approval ratings, his predecess...:2
# uob raises $2.4 million for charity with 1,500 clients, through the bank's annual lunar new year celebrations ...:2
# norman mailer (1923) american writer norman mailer was catapulted to fame at 25 with the publication of the na...:2
# philippines sea exploration deal with beijing, hanoi ruled unconstitutional the philippines supreme court on t...:2
# 'he is always perfect in my heart' wolf warrior zhao lijian has a big fan base in china. some boosters aren't ...:2
# tesla is expected to remain the ev leader for 2023 in his podcast addressing the markets today, louis navellie...:2
# vn-index secures 8-session winning streak - vnexpress international vietnam’s benchmark vn-index rose 0.81 per...:3
# us trade deficit reaches nearly $1 trillion: what does this say about the american economy? the us trade defic...:2
# can joe biden make his case for 4 more years? polls show a majority of americans are largely unaware of his su...:2
# emerging markets aim to capitalize on shifting semiconductor supply chains after the us levied sweeping restri...:2
# analysis: can biden make his case for 4 more years? polls show a majority of americans are largely unaware of ...:2
# which countries face the most geopolitical risk? the russia-ukraine war highlighted how geopolitical risk can ...:2
# analysis: biden confronts doubters with state of the union joe biden's state of the union address came at a cr...:2
# analysis: biden confronts doubters with state of the union joe biden's state of the union address came at a cr...:2
# analysis: biden confronts doubters with state of the union joe biden's state of the union address came at a cr...:2
# analysis: biden confronts doubters with state of the union joe biden's state of the union address came at a cr...:2
# long before feinstein, another california senator faced questions about mental fitness a similar situation pla...:2
# analysis: biden confronts doubters with state of the union biden left no doubt that he believes he has more wo...:2
# analysis: biden confronts doubters with state of the union biden left no doubt that he believes he has more wo...:2
# analysis: biden confronts doubters with state of the union biden left no doubt that he believes he has more wo...:2
# five classic sf works about cosmic warmongering there cannot be many heads of state who have not looked at map...:2
# on this day in history, feb. 6, 1911, president ronald reagan is born in illinois on this day in history, feb....:2
# half of the iphones will be made in india by 2027 the covid-19 pandemic and the constraints caused by it certa...:2
# polly mann, co-founder of wamm and leader in minnesota's antiwar movement, dies at 103 explaining her mission,...:2
# new zealand’s objectives for cptpp trade ministers from 11 nations will gather in auckland on matariki weekend...:2
# vn-index hits 6-week high - vnexpress international vietnam’s benchmark vn-index rose 0.61% to 1066.68 points ...:3
# halfway between brisbane and the gold coast, this city wants to be the next silicon valley. here's how logan, ...:2
# why party supporters think marit stiles, the ndp’s new leader, can take down doug ford as she takes on the lea...:2
# bloc confrontation leads nowhere, mutual benefit and win-win results prevail photo taken on may 28, 2021 shows...:2
# mccarthy, biden, and the washington snub the house speaker is reportedly still angry over a two-year-old incid...:2
# 50 books every man should read before he’s 50 the best books for men aren’t necessarily all what you might thi...:2
# how were the first 'voice mails' sent? in envelopes decades before mobile phones or answering machines, loved ...:2
# european shares slide as investors fear more rate hikes iseq overall index falls, led by banks and builders is...:3
# how richmond will spend $155 million in pandemic relief aid richmond is well on its way to spending its $155 m...:2
# 2022 annual report: letter to shareholders (marketscreener.com) in that order - and gives us the tools and ins...:2
# hrw urge asean chair indonesia to pressure myanmar on violence indonesia is under increasing pressure to use i...:2
# hrw urge asean chair indonesia to pressure myanmar on violence indonesia is under increasing pressure to use i...:2
# lecciones de brasil (y de estados unidos): desconfianza, crisis institucional y desigualdad "es evidente que e...:2
# jee main exam centre list 2023 released: download official list here! jee main exam centres 2023: nta has rele...:2
# vietnam political shakeup weakens technocrats and puts focus on security ousted nguyen xuan phuc oversaw fast ...:2
# economists radhika desai & michael hudson explain multipolarity, decline of us hegemony the new year gets off ...:2
# from watergate to jan. 6, leahy spanned the nation’s constitutional crises the vermont democrats hopes today’s...:2
# radhika desai and michael hudson discuss the causes and politicization of inflation desai and hudson debunk wi...:2
# impacto da reorganização das cadeias
# de valor na américa latina banco interamericano de desenvolvimento (bid) ...:2
# kaine, others reintroduce ‘reproductive freedom for all act’ it would prohibit states from enacting restrictio...:3
# lunar new year: history, significance and all you need to know about the year of the rabbit the lunar new year...:2
# vietnamese designers thrive on global stage - vnexpress international a growing number of international celebr...:2
# kimberly clark (kmb) q4 2022 earnings call transcript kmb earnings call for the period ending december 31, 202...:2
# don't worry if china isn't there, india can take care of the global supply chain india’s emergence as an alter...:2
# tu le to run for cabramatta as labor to allow a rank and file vote for nsw parliament seat tu le's political p...:2
# new lawsuits target state restrictions on abortion pills. here's what to know. supporters of abortion rights h...:2
# new lawsuits target state restrictions on abortion pills. here's what to know. supporters of abortion rights h...:2
# new lawsuits target state restrictions on abortion pills. here's what to know. supporters of abortion rights h...:2
# kimberly-clark corporation (kmb) q4 2022 earnings call transcript kimberly-clark corporation (nyse:nyse:kmb) q...:2
# mcleod russel in exclusive talks with carbon resources for ots to lenders the agreement expresses the parties'...:2
# coteccons construction : we prefer to call ourselves a humble giant (marketscreener.com)
#
#  with a view to cr...:2
# airport officials jailed for taking bribes from taxi operators former officials of an airport in central vietn...:2
# the political lies that really matter newly elected new york congressman george santos has "apologized" after ...:2
# ewy: long exposure to south korea's technology-focused economy ishares msci south korea capped etf provides in...:2
# beauty queen takes leaf out of mother's book in miss universe bid her australian mother founded a successful w...:2
# philippines sea exploration deal with beijing, hanoi ruled unconstitutional  ...:2
# inside the fight to save the peruvian amazon from big oil the survival of the world's biggest rainforest is cr...:2
# european democracy support annual review 2022 in a year dominated by the rhetoric of defending democracy, eu d...:2
# samsung free tv plus app might be coming to other brands samsung is reportedly gearing up to bring its free tv...:2
# fpt featured on globalive media’s technology series “beyond innovation” on bloomberg television hanoi, vietnam...:2
# vietnam data centre market landscape report 2023: space will grow by 45%, power by 44% and revenues by 58% to ...:2
# technology, telecommunications businesses benefit from digital economy technology and telecommunications busin...:2
# intel weighs boost to investment in vietnam chip packaging plant -sources hanoi (reuters) -intel corp is consi...:3
# exclusive-intel weighs boost to investment in vietnam chip packaging plant -sources hanoi (reuters) -intel cor...:3
# intel weighs boost to investment in vietnam chip packaging plant the possible move, which one source said coul...:2
# exclusive-intel weighs boost to investment in vietnam chip packaging plant -sources intel corp is considering ...:2
# exclusive-intel weighs boost to investment in vietnam chip packaging plant -sources hanoi :intel corp is consi...:2
# intel weighs boost to investment in vietnam chip packaging plant -sources hanoi : intel corp is considering a ...:2
# exclusive-intel weighs boost to investment in vietnam chip packaging plant -sources intel corp is considering ...:2
# intel eyes $1 billion vietnam chip plant investment boost intel is looking at bumping up its existing $1.5 bil...:2
# exclusive: intel weighs boosting investment in vietnam chip packaging plant – sources hanoi (reuters) -   inte...:2
# intel weighs boost to investment in vietnam chip packaging plant the possible move, which one source said coul...:2
# intel weighs boost to investment in vietnam chip packaging plant -sources intel corp <a href="https://www.reut...:3
# fpt software europe supports dax company covestro with cloud migration essen, germany--(business wire)-- #clou...:2
# asia-pacific b2c e-commerce market analysis report 2022-2023: focus on australia, china, india, indonesia, jap...:2
# asia-pacific b2c e-commerce market analysis report 2022-2023: focus on australia, china, india, indonesia, jap...:2
# asia-pacific b2c e-commerce market analysis report 2023: consumers and retailers increase their emphasis on su...:2
# asia-pacific b2c e-commerce market analysis report 2023: the delivery process still leaves room for improvemen...:2
# southeast asia data center construction market outlook & forecast report 2023: a $3+ billion industry by 2028 ...:2
# southeast asia data center construction market outlook & forecast report 2023: a $3+ billion industry by 2028 ...:2
# pm chinh’s singapore visit expected to advance bilateral trade ties prime minister pham minh chinh’s singapore...:2
# repairs for undersea internet cables to last from march to april domestic internet service providers sai don f...:2
# dấu ấn của kinh tế tư nhân trong lĩnh vực hạ tầng nhiều doanh nghiệp tư nhân để lại dấu ấn ở những lĩnh vực mà...:2
# according to arizton, massive investments by colocation & cloud service providers will grow southeast asia dat...:3
# according to arizton, massive investments by colocation & cloud service providers will grow southeast asia dat...:3
# according to arizton, massive investments by colocation & cloud service providers will grow southeast asia dat...:3
# afc on the road - vietnam vietnam is the key beneficiary in asia of shifting supply chains. tourism should mak...:2
# blackrock frontiers investment trust plc - portfolio update (marketscreener.com)
#
# blackrock frontiers investm...:2
# đồng yen mất giá kỷ lục, fpt việt nam vẫn thắng lớn tập đoàn công nghệ việt nam fpt vượt sóng gió ở thị trường...:1
# thai enterprises spend more on software amid growing digitalisation the majority of software spending in thail...:2
# us beauty queen crowned miss universe - vnexpress international miss usa r'bonney gabriel, a model and sewing ...:2
# expats get ‘stress-free life’ working in vietnamese tech - vnexpress international the desire to work in a bur...:2
# faulty internet cable encounters another problem the asia pacific gateway (apg) internet cable, which connects...:2
# southeast asia data center construction market outlook report 2023-2028 - 5g deployments will drive edge data ...:2
# prime minister visits university of brunei darussalam prime minister pham minh chinh and his spouse visited th...:2
# stock trading jumps 42% - vnexpress international vietnam’s benchmark vn-index rose 0.36% to 1060.17 points fr...:3
# vn-index secures 8-session winning streak - vnexpress international vietnam’s benchmark vn-index rose 0.81 per...:3
# the neo-nazi hunter next door kris goldsmith has seen too many veterans get tricked into equating patriotism w...:2
# disorder in the house: frauds, dimwits and grenades 'r us house gopers just turned their first oversight heari...:2
# al brown, star of ‘the wire,’ dead at 83 brown's daughter jenny confirmed the sad news to tmz in a statement s...:2
# 'the wire' star al brown dead at 83 al brown -- famous from 'the wire' -- has died ... this according to his l...:2
# al brown, ‘the wire’ actor known for playing col. stan valchek, dies at 83 al brown, the actor best known for ...:2
# cadence13 ‘weaponized’ podcast explores the unknown with investigative reporters jeremy corbell and george kna...:2
# when ‘whataboutism’ is ok those who try to shut down debate deserve to be scorned. but when wrongdoing is equi...:2
# 2 free games are available now at epic the epic games store continues to give away free games each week, more ...:3
# 100 essential movies every guy should see cinematic history is littered with gems. in the hands of a brilliant...:2
# gop rep. cory mills hands out grenades to house members « it is my pleasure to give you a 40mm grenade ... man...:2
# mitch mcconnell, you’re no mike mansfield as the 118th congress convened, public attention understandably
# focu...:2
# dc insider: this 'grotesque' gop-controlled committee has one goal the house oversight and accountability comm...:2
# crime and un-punishment: republicans have a new roadmap for a better coup donald trump's coup attempt on jan. ...:2
# this week's free game is available at epic the epic games store continues to give away free games each week, m...:2
# did j. edgar hoover order the assassination of martin luther king jr? all global research articles can be read...:2
# editorial: mlk’s chicago setback looks more like a victory today was martin luther king, jr. outfoxed by chica...:2
# did the fbi’s charles mcgonigal help throw the 2016 election to trump? in the course of writing two books on d...:2
# the best bites for every price: $10 and under the best food you can find in seattle for $10 or less.
#
#  by ann...:2
# setting the record straight in a coindesk exclusive, the co-founder of yuga labs, wylie aronow, shares a frank...:2
# why did the national guard take so long to get to the capitol on january 6? the acting secretary of defense at...:2
# evelyn west: the life and times of a st. louis legend on jan. 27, 1977, a st. louis judge issued an order clos...:2
# more than a meal: how white house dinners shape presidential policy “you can’t even consider the history of th...:2
# playbook: biden’s no-compromise sotu and the pentagon said that china had rejected a request from defense secr...:2
# corky lee and the work of seeing there is a symmetry between corky lee’s passing and the rise of anti-asian ha...:2
# muhammad ali (1942) the self-proclaimed "greatest of all time," ali is celebrated as much for his flamboyant m...:2
# the 40 best movies on netflix this week stuck for a good film on netflix? here are our picks for the best netf...:2
# những công nhân xa quê trên chuyến bay đoàn viên chuyến bay của vietnam airlines cất cánh hôm 9/1 đưa hàng tră...:2
# gỗ trường thành vào top 500 doanh nghiệp tư nhân lớn nhất việt nam tập đoàn kỹ nghệ gỗ trường thành (ttf) vào ...:2
# dấu ấn của kinh tế tư nhân trong lĩnh vực hạ tầng nhiều doanh nghiệp tư nhân để lại dấu ấn ở những lĩnh vực mà...:2
# boe - nhà cung ứng của apple và samsung muốn xây nhà máy ở việt nam đối tác cung ứng màn hình cho cả 2 gã khổn...:2
# ban mai - cô bé mắc chứng khó đọc thành hoa hậu ban mai từng là cô bé mắc chứng khó đọc, vươn lên thành sinh v...:2
# deaths on location: how the ‘twilight zone’ and ‘midnight rider’ tragedies may influence ‘rust’ prosecution on...:2
# cổ phiếu hòa phát hút tiền nhà đầu tư ngoại giá chạm đáy hai năm trong khi triển vọng tăng trưởng dài hạn tích...:3
# h'hen niê: 'tôi trải qua một năm kỳ diệu' hoa hậu h'hen niê nói có một năm hoạt động tích cực, thử sức với vai...:2
# táo quân 2023: tiếng cười nhẹ nhàng chương trình táo quân 2023 giảm tính đả kích, tạo tiếng cười nhẹ nhàng khi...:1
# mai ngô giúp mẹ bán hoa tết tp hcm- á hậu mai ngô cùng em gái phụ mẹ bán hoa những ngày giáp tết quý mão. tp h...:1
# deaths on location: how the ‘twilight zone’ and ‘midnight rider’ tragedies may influence ‘rust’ prosecution on...:2
# bamboo airways và baa training vietnam hợp tác đào tạo phi công mpl chương trình dự kiến đào tạo 100 học viên ...:2
# hàng không năm 2022 - bay nhiều vẫn lỗ du lịch phục hồi nhưng năm 2022, vietnam airlines, vietjet vẫn chịu nhi...:3
# uscirf tiếp tục kêu gọi trả tự do cho ông nguyễn bắc truyển ủy ban tự do tôn giáo quốc tế của hoa kỳ (uscirf) ...:1
# đạo đức trong influencer marketing: minh bạch trong thông tin tài trợ là yếu tố quan trọng nhất trong nhiều nă...:2
# khách mời bàn về thăng trầm của điện ảnh việt charlie nguyễn, bình bồng bột... cùng các khách mời bàn về thăng...:2
# khách mời vietnam cinema bàn về thăng trầm của điện ảnh việt charlie nguyễn, bình bồng bột... cùng các khách m...:2
# sacombank nhận hai giải thưởng về thương hiệu sacombank nhận giải thưởng thương hiệu vàng tp hcm năm 2022 và t...:2
# đại sứ anh iain frew: 'tôi hoà mình vào truyền thống tết của việt nam' đại sứ anh gửi lời chúc mừng năm mới bằ...:2
# biển đông có yên tĩnh không? khi giới thiệu thư chúc tết của ông tập cận bình gửi ông trọng với thiên hạ, trun...:2
# [qc] thực hư lời đồn robot hút bụi “toàn năng, đột phá” của 2 siêu phẩm nhà ecovacs tích hợp thêm nhiều chức n...:2
# bảy nỗi sợ tôi vừa tiễn một đoàn khách pháp 10 người, đi du thuyền hạ long tham quan hai ngày một đêm. tôi vừa...:2
# 7 nỗi sợ của du khách tôi vừa tiễn một đoàn khách pháp 10 người, đi du thuyền hạ long tham quan hai ngày một đ...:2
# ngọc châu catwalk kiểu 'hoa sen' ở bán kết miss universe mỹ- người đẹp diện đầm dạ hội của chung thanh phong, ...:2
# các nhà báo mỹ và vn nói gì về lối làm truyền thông của vinfast? kevin williams nói với bbc news tiếng việt v...:2
# vụ nữ sinh huflit: cần minh bạch thông tin thay vì đòi xử lý người đưa tin! trường quân sự quân khu 7 bác bỏ t...:2
# nhiều hoạt động tương tác và quà tặng tại momo lắc xì 2023 thông qua lắc xì 2023 với nhiều quà tặng giá trị, m...:2
# học cách đặt câu hỏi sang tuổi 22, tôi bắt đầu học tiếng đức, như vậy là hơi muộn để bắt đầu. nhưng tôi tin rằ...:2
# nashtech mở văn phòng mới tại đà nẵng nashtech khai trương văn phòng mới tại đà nẵng hôm 13/11, tại tầng 19, t...:2
# việt nam sẽ là câu chuyện kinh tế thú vị nhất năm 2023 việt nam đang ngày càng nhận được sự quan tâm của toàn ...:2
# hoa hậu ngọc châu phủ nhận khai gian bằng cấp hoa hậu ngọc châu, 28 tuổi, xác nhận chưa tốt nghiệp đại học tôn...:2
# 'nhà bà nữ doanh thu cao nhưng không bứt phá chất lượng' không thể chỉ dựa vào doanh thu thì có thể kết luận p...:2
# khả năng huỷ niêm yết cổ phiếu vietnam airlines ngày 2/2, sở giao dịch chứng khoán tp.hcm đã có thông báo gửi ...:2
# tập đoàn đông dương đặt mục tiêu mở rộng 300 cửa hàng toàn quốc doanh nghiệp hướng đến tạo dựng hệ sinh thái c...:2
# nhiều cơ hội đặt phòng khách sạn và tour chơi tết giờ chót sức mua năm nay thấp nên hiện khách sạn hoặc tour c...:2
# nhiều cơ hội đặt khách sạn và tour chơi tết giờ chót sức mua năm nay thấp nên hiện khách sạn hoặc tour cho mùn...:2
# degaussing system market worth $740 million by 2027 - exclusive report by marketsandmarkets™ the degaussing sy...:3
# degaussing system market worth $740 million by 2027 - exclusive report by marketsandmarkets™ chicago, jan. 16,...:3
# bí quyết chạy ultra của runner đà nẵng đà nẵng- bận rộn với con nhỏ, công việc ở xa nhà, nhưng nguyễn minh tuấ...:2
# burt bacharach, the essence of pop music success, dies at 94 seen by some as his generation's greatest songwri...:2
# burt bacharach, the essence of pop music success, dies at 94 los angeles — at the brill building, the legendar...:2
# runner cả nước sẵn sàng cho giải chạy đêm tp hcm 10.000 vđv, trong đó có những tên tuổi hàng đầu sẽ có mặt tại...:2
# runner sẵn sàng cho giải chạy đêm tp hcm 10.000 vđv, trong đó có những tên tuổi hàng đầu, sẽ có mặt tại tp hcm...:2
# runner đổ về tp hcm dự giải chạy đêm 10.000 vđv, trong đó có những tên tuổi hàng đầu sẽ có mặt tại tp hcm vào ...:2
# cơ hội thoát vùng an toàn, thử thách bản thân tại unilever chị minh nguyệt - giám đốc kênh hiện đại và thương ...:2
# hoa hậu mai phương xin lỗi khán giả hoa hậu mai phương, 23 tuổi, xin lỗi khán giả vì bị nhiều người chỉ trích ...:2
# mv của trọng hiếu vào chung kết eurovision song contest đức "dare to be different" của trọng hiếu là một trong...:2
# vietinbank lì xì khách hàng đầu xuân ngân hàng dành tặng lì xì bằng tiền mặt cùng hàng nghìn combo tài lộc cho...:2
# người dùng chuộng thanh toán online nhiều người chọn mua sắm, thanh toán với thẻ tín dụng vib để hưởng bộ ba ư...:2
# 30 sff titles to look forward to in 2023 i’m calling it first sentence euphoria. it’s that feeling you get whe...:2
# võ hoàng yến hội ngộ bạn trai ở mỹ người mẫu võ hoàng yến du lịch, mua sắm, dành thời gian bên bạn trai tại mỹ...:2
# h'hen niê: 'tôi không còn khóc khi bị chê' hoa hậu h'hen niê nói hiện trưởng thành, đối mặt mọi thứ với tâm lý...:2
# h'hen niê: 'tôi không còn khóc một mình khi bị chê' hoa hậu h'hen niê nói hiện trưởng thành, đối mặt mọi thứ v...:2
# chấp thuận cho việt nam cử 20 đội tham gia vex robotics hà nội (sputnik) - việt nam được cử 20 đội chơi tham g...:2
# aeon mall bình tân hoàn tất cải tạo trước thềm năm mới ngoài mở 24 gian hàng mới, aeon mall bình tân hoàn tất ...:2
# mặt số đồng hồ có bản đồ việt nam lập kỷ lục lần đầu tiên mặt số đồng hồ tráng men cloisonné tạo hình bản đồ v...:2
# đồng hồ lập kỷ lục có chi tiết bản đồ việt nam nhỏ nhất lần đầu tiên mặt số đồng hồ tráng men cloisonné tạo hì...:2
# how zimbabwe's pangolins are being given a second chance... [263chat] zimbabwe's wildlife landscape is endowed...:2
# 'du lịch việt nam có đủ yếu tố để vượt qua thái lan' ngành du lịch việt nam trong hơn một thập kỷ qua đã ghi n...:2
# remembering burt bacharach burt bacharach, who is among the musical giants of our era, passed away at the age ...:2
# hàn quốc lần đầu tiên thừa nhận tội ác của binh lính hàn đã gây ra tại việt nam tuần này, chúng...:2
# vietnam airlines nối thêm đường bay đến trung quốc trong hai tháng tới, 9/10 chặng bay đến trung quốc - thị tr...:2
# top 11 chiến lược marketing ngành fmcg năm 2023 - cleverads chiến lược marketing ngành fmcg là gì? nó đem lại ...:2
# thẻ tín dụng vib travel elite nhiều ưu đãi dịp tết thẻ vib travel elite giúp tích lũy dặm thưởng, đặc quyền ph...:3
# lương nhân sự trung cao cấp khả năng tăng 5-25% năm nay khảo sát của một số hãng tuyển dụng cho biết lao động ...:3
# tân uỷ ban việt nam ở quốc hội mỹ cam kết thúc đẩy nhân quyền bốn lãnh đạo mới của uỷ ban việt nam (vietnam ca...:2
# gia tăng xuất khẩu lao động và cải thiện thứ hạng về tệ nạn... ‘buôn người’ (p3) báo cáo tip 2022 cho thấy cộn...:2
# lần đầu tiên học sinh việt dự giải đấu robotics lớn nhất thế giới 20 đội thi của học sinh việt nam sẽ tranh tà...:2
# lần đầu tiên học sinh việt dự giải vô địch robotics lớn nhất thế giới lần đầu tiên, 20 đội thi của học sinh vi...:2
# vn-index secures 8-session winning streak - vnexpress international vietnam’s benchmark vn-index rose 0.81 per...:3
# chính sách đối ngoại của việt nam sẽ nghiêng về phía nào? tuần này, trên báo chí nga và nước ngoài có...:2
# đại sứ hoa kỳ gửi thiệp chúc tết tới trẻ khiếm thị đại sứ hoa kỳ marc knapper và phu nhân mới làm thiệp chữ nổ...:2
# nhu cầu về các sản phẩm "made in vietnam" đang chậm lại vinacapital cho rằng, tăng trưởng gdp của việt nam sẽ ...:1
# gia tăng xuất khẩu lao động và cải thiện thứ hạng về tệ nạn... ‘buôn người’ (p2) ngoài việt nam còn có campuch...:1
# xu hướng marketing “neo giữ” ký ức: khi người tiêu dùng có xu hướng tìm về những giá trị tích cực trong quá kh...:2
# sống trong nhà thông minh hà nội- thiết bị thông minh cho phép anh minh điều khiển mọi thứ trong nhà từ bật cô...:2
# đảng cộng sản việt nam tròn 93 tuổi và tầm nhìn 2045 từ các phía một số thách thức cho đảng cộng sản việt...:2
# việt nam treo thưởng 1 triệu đô cho huy chương vàng olympic mỗi vận động viên việt nam giành được huy chương v...:3
# ứng dụng content marketing vào quá trình ứng tuyển: bí quyết tăng khả năng nhận việc trong thị trường cạnh tra...:2
# baldwin, brandon lee, fantozzi: quando il cinema diventa un reato non solo "rust": la storia del cinema è pien...:2
# partial validation of a taqman quantitative polymerase chain reaction for the detection of the three genotypes...:2
# om duimen en vingers bij af te likken: deze 23 culinaire nieuwkomers verdienen in 2023 een plek op uw radar be...:2
# 2023 – năm của ‘vận mệnh tương quan’? việt nam cũng đề cập đến sự kiện ông tập cận bình và ông nguyễn phú trọn...:2
# lần đầu tiên little saigon có phố hoa ngày tết lần đầu tiên cộng đồng người việt ở mỹ dựng phố hoa vào ngày tế...:2
# 5 xu hướng marketing trong năm 2023: trải nghiệm người dùng là ưu tiên hàng đầu sự thay đổi liên tục trong hàn...:2
# đồng yen mất giá kỷ lục, fpt việt nam vẫn thắng lớn tập đoàn công nghệ việt nam fpt vượt sóng gió ở thị trường...:1
# thiết kế việt thăng hoa trên trường quốc tế các thiết kế việt ngày càng được nhiều ngôi sao và khách nước ngoà...:2
# ‘hồng phúc’ từ những... ‘chị’... trang, ‘anh’ triết,... dẫu cha, chú của các “anh”, các “chị” như “anh” triết,...:2
# nửa thế kỷ cải tạo làm cạn kiệt tài nguyên một đbscl đang chết dần kế hoạch phát triển nào thì cũng phải tính ...:2
# vietnam attends fifth international conference for world balance a vietnamese delegation led by deputy head of...:2
# asia direct cable (adc) lands hong kong segment at sunevision's cable landing station china telecom global lim...:2
# asia direct cable (adc) lands hong kong segment at sunevision's cable landing station china telecom global lim...:2
# asia direct cable (adc) lands hong kong segment at ... - pr newswire /prnewswire/ -- china telecom global limi...:2
# asia direct cable (adc) lands hong kong segment at sunevision's cable landing station to enable 1-stop-shop co...:2
# asia direct cable (adc) lands hong kong segment at sunevision's cable landing station to enable 1-stop-shop co...:2
# asia direct cable (adc) lands hong kong segment at sunevision's cable landing station to enable 1-stop-shop co...:2
# vn-index continues sideways - vnexpress international vietnam’s benchmark vn-index rose 0.06% to 1,056.39 poin...:3
# vn-index hits 6-week high - vnexpress international vietnam’s benchmark vn-index rose 0.61% to 1066.68 points ...:3
# vn-index secures 8-session winning streak - vnexpress international vietnam’s benchmark vn-index rose 0.81 per...:3
# 10 best budget-friendly vacation destinations for 2023 when it comes to planning a vacation, budget is, for ma...:2
# korean war wall is littered with goofs "it’s just a damn mess." that’s how historian hal barker describes the ...:2
# efemérides del 9 de febrero de 2023: ¿qué pasó el 9 de febrero? estos fueron los 2 acontecimientos más importa...:2
# rich nations pledged to pay for climate damages. where’s the money? there were high hopes in november when a g...:2
# para kazandıran uygulamalar abd merkezli yapay zeka şirketi openai tarafından geliştirilen ve geçen aralık ayı...:2
# u.s. climate envoy kerry outlines carbon offset initiative for developing nations abu dhabi (reuters) - u.s. c...:2
# virginia boy who shot teacher abigail zwerner told another he wanted to set her on fire (pic of the boy releas...:2
# ...
# halfway between brisbane and the gold coast, this city wants to be the next silicon valley. here's how logan, ...:2
# why party supporters think marit stiles, the ndp’s new leader, can take down doug ford as she takes on the lea...:2
# bloc confrontation leads nowhere, mutual benefit and win-win results prevail photo taken on may 28, 2021 shows...:2
# mccarthy, biden, and the washington snub the house speaker is reportedly still angry over a two-year-old incid...:2
# 50 books every man should read before he’s 50 the best books for men aren’t necessarily all what you might thi...:2
# how were the first 'voice mails' sent? in envelopes decades before mobile phones or answering machines, loved ...:2
# european shares slide as investors fear more rate hikes iseq overall index falls, led by banks and builders is...:3
# how richmond will spend $155 million in pandemic relief aid richmond is well on its way to spending its $155 m...:2
# 2022 annual report: letter to shareholders (marketscreener.com) in that order - and gives us the tools and ins...:2
# hrw urge asean chair indonesia to pressure myanmar on violence indonesia is under increasing pressure to use i...:2
# hrw urge asean chair indonesia to pressure myanmar on violence indonesia is under increasing pressure to use i...:2
# lecciones de brasil (y de estados unidos): desconfianza, crisis institucional y desigualdad "es evidente que e...:2
# jee main exam centre list 2023 released: download official list here! jee main exam centres 2023: nta has rele...:2
# vietnam political shakeup weakens technocrats and puts focus on security ousted nguyen xuan phuc oversaw fast ...:2
# economists radhika desai & michael hudson explain multipolarity, decline of us hegemony the new year gets off ...:2
# from watergate to jan. 6, leahy spanned the nation’s constitutional crises the vermont democrats hopes today’s...:2
# radhika desai and michael hudson discuss the causes and politicization of inflation desai and hudson debunk wi...:2
# impacto da reorganização das cadeias
# de valor na américa latina banco interamericano de desenvolvimento (bid) ...:2
# kaine, others reintroduce ‘reproductive freedom for all act’ it would prohibit states from enacting restrictio...:3
# lunar new year: history, significance and all you need to know about the year of the rabbit the lunar new year...:2
# vietnamese designers thrive on global stage - vnexpress international a growing number of international celebr...:2
# kimberly clark (kmb) q4 2022 earnings call transcript kmb earnings call for the period ending december 31, 202...:2
# don't worry if china isn't there, india can take care of the global supply chain india’s emergence as an alter...:2
# tu le to run for cabramatta as labor to allow a rank and file vote for nsw parliament seat tu le's political p...:2
# new lawsuits target state restrictions on abortion pills. here's what to know. supporters of abortion rights h...:2
# new lawsuits target state restrictions on abortion pills. here's what to know. supporters of abortion rights h...:2
# new lawsuits target state restrictions on abortion pills. here's what to know. supporters of abortion rights h...:2
# kimberly-clark corporation (kmb) q4 2022 earnings call transcript kimberly-clark corporation (nyse:nyse:kmb) q...:2
# mcleod russel in exclusive talks with carbon resources for ots to lenders the agreement expresses the parties'...:2
# coteccons construction : we prefer to call ourselves a humble giant (marketscreener.com)
#
#  with a view to cr...:2
# airport officials jailed for taking bribes from taxi operators former officials of an airport in central vietn...:2
# the political lies that really matter newly elected new york congressman george santos has "apologized" after ...:2
# ewy: long exposure to south korea's technology-focused economy ishares msci south korea capped etf provides in...:2
# beauty queen takes leaf out of mother's book in miss universe bid her australian mother founded a successful w...:2
# philippines sea exploration deal with beijing, hanoi ruled unconstitutional  ...:2
# inside the fight to save the peruvian amazon from big oil the survival of the world's biggest rainforest is cr...:2
# european democracy support annual review 2022 in a year dominated by the rhetoric of defending democracy, eu d...:2
# samsung free tv plus app might be coming to other brands samsung is reportedly gearing up to bring its free tv...:2
# punisher: il braccio violento della casa delle idee punisher, dalla violenza del vietnam alla guerra al crimin...:2
# quando la politica italiana era dalla parte degli oppressi negli anni sessanta e settanta del novecento, l’afr...:2
# “via dal vietnam, troppo inquinamento. l’italia ha più pregi che difetti e vogliamo valorizzarla col nostro la...:2
# i pervestiti di sanremo – da orietta berti vestita da "strisce pedonali" al "reazionario" celentano in coppia ...:2
# le uscite bao publishing di febbraio 2023 tutte le uscite bao publishing di febbraio 2023 fra cui essere monta...:2
# l’india dei sorpassi clamorosi ora vacilla sotto il maxi scandalo adani il miracolo indiano è la storia di suc...:2
# zelensky chiede un’assemblea straordinaria dell’onu il 24 febbraio, nell’anniversario dell’invasione il presid...:2
# le crociere da fare nel 2023 contemplare il mondo dall’acqua, navigando canali, mari e oceani. la crociera off...:2
# sace, da incertezza politica e clima i maggiori rischi per le imprese che esportano  ...:2
# sace: rischio politico in peggioramento per l’export italiano. rotta puntata sulle economie emergenti il grupp...:2
# levi’s, un secolo e mezzo in denim: il compleanno dei 501 amati da marlon brando, bob dylan e steve jobs il mo...:2
# altro passo verso l'europa di vinfast: e.on drive incaricata di installare colonnine nelle sedi europee il cos...:2
# tornare a parlare maori dopo decenni di repressione, la cultura dei nativi della nuova zelanda ha ricominciato...:2
# breve storia delle azioni segrete degli stati uniti in patria e all'estero molto prima dell'attacco al nord st...:2
# runner cả nước sẵn sàng cho giải chạy đêm tp hcm 10.000 vđv, trong đó có những tên tuổi hàng đầu sẽ có mặt tại...:2
# runner sẵn sàng cho giải chạy đêm tp hcm 10.000 vđv, trong đó có những tên tuổi hàng đầu, sẽ có mặt tại tp hcm...:2
# runner đổ về tp hcm dự giải chạy đêm 10.000 vđv, trong đó có những tên tuổi hàng đầu sẽ có mặt tại tp hcm vào ...:2
# vietnam airlines tiếp tục tăng hơn 100 chuyến bay tết vietnam airlines vừa tăng 20.000 chỗ ngồi, tương đương 1...:3
# crescono gli iphone made in india sempre più iphone saranno prodotti in india nei prossimi anni.
# link all'art...:2
# la metà di tutti gli iphone sarà costruita in india nel 2027 la metà di tutti gli iphone potrebbe essere prodo...:2
# wyndham hotels & resorts asia pacific expands presence in vietnam with wyndham danang golden bay standing at 2...:2
# nel 2027 un iphone su due sarà ‘made in india’: fine della leadership cinese? secondo un nuovo rapporto ripres...:2
# "indagare su ingerenze iraniane e russe. la cina? non è un modello da seguire" la politica estera del governo ...:2
# il buddhismo in libertà: «dai maestri zen ai successi di maté» non solo spiritualità orientale: la casa editri...:2
# i 52 posti da vedere nel 2023 secondo il new york times 52 posti da vedere nel 2022 secondo il new york times:...:2
# i predatori degli alberi la cambogia detiene il record mondiale di deforestazione illegale e, grazie alla comp...:2
# apple: «in italia il record storico di vendite di iphone» luca maestri ottimista sulle vendite di iphone. il r...:2
# apple, in italia il record storico di vendite di iphone luca maestri ottimista sulle vendite di iphone. il rec...:3
# l’accordo militare usa-filippine in chiave anti-cina e altre notizie interessanti le notizie interessanti di o...:2
# masterchef italia 12: i top e i flop della settima puntata a masterchef italia 12 ci si prende un po' troppo s...:2
# notebook, nel primo trimestre si prevedono consegne al lumicino secondo quanto riportano gli analisti di trend...:2
# il calo demografico cinese, il piano industriale del green deal e altre notizie interessanti le notizie intere...:2
# ‘hồng phúc’ từ những... ‘chị’... trang, ‘anh’ triết,... dẫu cha, chú của các “anh”, các “chị” như “anh” triết,...:2
# bamboo airways và baa training vietnam hợp tác đào tạo phi công mpl chương trình dự kiến đào tạo 100 học viên ...:2
# masterchef 12, francesco contro hué: «sei un altro elemento del clan» eliminati nicola e ollivier, ora gli asp...:2
# baldwin, brandon lee, fantozzi: quando il cinema diventa un reato non solo "rust": la storia del cinema è pien...:2
# perché i tank non bastano all’ucraina (e cosa non abbiamo capito) la scelta di germania e stati uniti di forni...:2
# marc ruskin l’infiltrato per vent’anni è stato un agente dell’fbi specializzato nelle operazioni sotto copertu...:2
# ho affrontato un trapianto di capelli a basso costo in turchia, il recupero è stato un'agonia ma lo rifarei se...:2
# gia tăng xuất khẩu lao động và cải thiện thứ hạng về tệ nạn... ‘buôn người’ (p2) ngoài việt nam còn có campuch...:1
# la confetteria storica più antica d'italia ha costretto i milanesi a rallentare a due passi dal duomo, ha aper...:2
# in namibia è un brutto momento per i rinoceronti nel 2022 i bracconieri ne hanno uccisi 87, quasi il doppio ri...:3
# mặt số đồng hồ có bản đồ việt nam lập kỷ lục lần đầu tiên mặt số đồng hồ tráng men cloisonné tạo hình bản đồ v...:2
# đồng hồ lập kỷ lục có chi tiết bản đồ việt nam nhỏ nhất lần đầu tiên mặt số đồng hồ tráng men cloisonné tạo hì...:2
# bà mai kiều liên kể về lon sữa bột 'made in vietnam' đầu tiên nhìn nhà máy "đắp chiếu" sau chiến tranh, ít ai ...:2
# larve della farina: via libera dall’ue alla messa in commercio come alimento a partire dal 26 di gennaio le la...:2
# larve della farina commestibili come nuovo alimento: il via libera dell’ue dal 26 gennaio le proteine derivant...:2
# cosmetica, 2023 con previsioni di vendite record trainate dall’estero il settore dovrebbe raggiungere un fattu...:3
# zelensky a sanremo, le “ospitate” del presidente ucraino e il rischio della banalizzazione della realtà a quas...:2
# bob dylan sulla guerra – ‘’durante la seconda guerra mondiale, prima delle bombe su hiroshima e nagasaki, in u...:2
# il premio pulitzer hersh: “esplosioni del nord stream ordinate e organizzate da casa bianca e cia”. washington...:2
# enzo favata in vietnam per serata dedicata a musica italiana il musicista e compositore sardo enzo favata rito...:2
# enzo favata in vietnam per serata dedicata a musica italiana il musicista e compositore sardo enzo favata rito...:2
# prehistoric pathways to anthropocene adaptation: evidence from the red river delta, vietnam over the past twen...:2
# stati uniti vs cina: la nuova frontiera della guerra sono i chip tra washington e pechino le tensioni sono all...:2
# le elezioni che potrebbero decidere la guerra a marzo del 2024 si terranno le presidenziali in russia e in ucr...:2
# “perfetti sconosciuti”, “perfectos desconocidos”, “τέλειοι ξένοι”, eccetera eccetera il film del 2016 di paolo...:2
# “perfetti sconosciuti”, “perfectos desconocidos”, “τέλειοι ξένοι”, eccetera il film del 2016 di paolo genovese...:2
# dove vengono archiviati i dati degli utenti di tiktok? tiktok è tra le piattaforme più usate al mondo, sia per...:2
# các nhà báo mỹ và vn nói gì về lối làm truyền thông của vinfast? kevin williams nói với bbc news tiếng việt v...:2
# paolo bonolis e la nuova edizione di “avanti un altro!” il conduttore presenta le novità della nuova edizione ...:2
# turismo, italia regina di ospitalità: polignano a mare il luogo più accogliente al mondo l'undicesima edizione...:2
# tank abrams, cosa sono i supercarri usa e perché possono cambiare il corso della guerra - ilmessaggero.it <ol>...:2
# 15 travel ideas to explore vietnam’s hidden gems - vnexpress international australia’s lonely planet magazine ...:2
# guerra ucraina: usa verso invio carri armati abrams, tra i più potenti al mondo - sky tg24 <ol><li>guerra ucra...:2
# thay lãnh đạo cấp cao, vn bước vào giai đoạn 'làm ăn cần thận trọng’? việc thay lãnh đạo cấp cao như ông ...:2
# ford mustang, la ponycar per tutti la ford mustang viene presentata al new york world's fair del 1964. il mito...:2
# industria: comparto home oltre 158 mld, export italia +11,2% il commercio mondiale del comparto home ha confer...:3
# bosch: nel 2023 la produzione auto andrà a bassa velocità la compagnia tedesca stima per il 2023 un leggero au...:3
# karl marlantes, cronache dal mio vietnam errori e orrori di guerra, ma anche spirito di corpo. in libreria per...:2
# il capodanno cinese senza restrizioni in cina con la fine della strategia “zero covid”, milioni di cinesi hann...:2
# apple a čína aneb 13. komnata kalifornského giganta v kostce designed in california, made in china, stojí na o...:2
# mercedes-benz classe g, il giro del mondo di "otto" gunther holtorf ha viaggiato per 26 anni insieme alla sua ...:2
# i film premiati agli oscar non hanno più il successo di una volta i vincitori delle categorie più importanti e...:2
# sony future filmmaker awards 2023 - annunciata la shortlist della prima edizione le candidature sono state rac...:2
# homi detta i nuovi canoni del lifestyle padiglioni di fiera milano affollati di visitatori e buyer italiani e ...:2
# gia tăng xuất khẩu lao động và cải thiện thứ hạng về tệ nạn... ‘buôn người’ (p3) báo cáo tip 2022 cho thấy cộn...:2
# bce, ecco perché nonostante i rialzi resta accomodante. la lezione degli anni settanta e il monito ai politici...:2
# cosa possiamo imparare dagli impatti dei cambiamenti climatici del passato? un nuovo studio, guidato dalla pro...:2
# la pace si allontana – la guerra in ucraina è entrata ufficialmente in una fase di stallo, che durerà fino all...:2
# tutti i principali film di netflix in uscita nel 2023 buone notizia, i film netflix in uscita questo 2023 sono...:2
# người dùng chuộng thanh toán online nhiều người chọn mua sắm, thanh toán với thẻ tín dụng vib để hưởng bộ ba ư...:2
# roma prima città al mondo per il cibo: i viaggiatori premiano di tripadvisor premiano la capitale quarto posto...:2
# i palloni cinesi sono in giro da un pezzo, dicono gli stati uniti i servizi di intelligence e il pentagono sta...:2
# sace, obiettivo 650 miliardi per l’export targato made in italy il gruppo che assicura le imprese italiane sui...:3
# il seiko 5 sports è il miglior orologio da cui iniziare la tua collezione ci sono diversi motivi per cui una p...:2
# pane con farina di grilli. e lo chef pluripremiato viene insultato sui social piovono insulti sul giovane chef...:2
# ci voleva un premio pulitzer per svelare il segreto di pulcinella: il nord stream è stato sabotato dagli ameri...:2
# la yamaha xt 250 e la fuga con rambo l'agile moto con cui l'eroe cinematografico sfuggì alla polizia è diventa...:2
# thẻ tín dụng vib travel elite nhiều ưu đãi dịp tết thẻ vib travel elite giúp tích lũy dặm thưởng, đặc quyền ph...:3
# “il rischio autoritarismo? ma figurati. poteva pensarlo solo chi ha impostato la sciagurata campagna elettoral...:2
# lương nhân sự trung cao cấp khả năng tăng 5-25% năm nay khảo sát của một số hãng tuyển dụng cho biết lao động ...:3
# università bari inaugura anno accademico nel segno della pace le guerre in corso nel mondo, i tanti conflitti ...:2
# il nuovo rushdie, veronesi e zeller, il vietnam di marlantes: «la lettura» è in edicola e app nell’inserto in ...:2
# il generale kellogg: «il destino della guerra si decide in primavera» secondo il generale, ex consigliere per ...:2
# treviso, cerca il padre e lo trova negli usa: «mi dissero che era morto, ora parliamo tutti i giorni» michela ...:2
# scb bị điều tra vì ‘biến gửi tiết kiệm thành mua bảo hiểm’ ngân hàng scb, vốn bị tố cáo dụ dỗ khách hàng gửi t...:2
# il furgone più famoso? quello dell’a-team per i bambini degli anni '80, quel furgone nero con la striscia ross...:2
# brics, anche l'egitto nella lista dei candidati l'egitto è entrato a far parte dell'elenco dei paesi che aspir...:2
# the sympathizer: robert downey jr. irriconoscibile nella serie di park chan-wook! dalle prime foto trapelate d...:2

# %% [markdown]
# #Result

# %%
in_data['title_labels'] = labels

# %%
in_data.to_csv("newsapi_articles.csv")

# %%
process = News_Process()
process.set_df(in_data)
process.visualize_news()
print("\n--> Looking into full_labels")
process.drill_down("full_labels")
process.drill_down("title_labels")
# Out:
# Ready to process news
#          date                                              title  \
# 0  2023-01-18  người dùng chuộng thanh toán online nhiều ngườ...
# 1  2023-01-23  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...
# 2  2023-01-13  vietnam international commercialbank : payment...
# 3  2023-01-12  vn-index continues sideways - vnexpress intern...
# 4  2023-01-12  nhiều hoạt động tương tác và quà tặng tại momo...
#
#                                          description stock_group  \
# 0  nhiều người chọn mua sắm, thanh toán với thẻ t...         VIB
# 1  thẻ vib travel elite giúp tích lũy dặm thưởng,...         VIB
# 2  (marketscreener.com) \n \n vietnam internation...         VIB
# 3  vietnam’s benchmark vn-index rose 0.06% to 1,0...         VIB
# 4  thông qua lắc xì 2023 với nhiều quà tặng giá t...         VIB
#
#                                              combine  full_labels  \
# 0  người dùng chuộng thanh toán online nhiều ngườ...            2
# 1  thẻ tín dụng vib travel elite nhiều ưu đãi dịp...            3
# 2  vietnam international commercialbank : payment...            2
# 3  vn-index continues sideways - vnexpress intern...            3
# 4  nhiều hoạt động tương tác và quà tặng tại momo...            2
#
#    title_labels
# 0             2
# 1             3
# 2             2
# 3             3
# 4             2
#
# --->Data shape (1781, 7)
#
# --->Unique values of each column
# date             33
# title           552
# description     530
# stock_group      33
# combine         552
# full_labels       3
# title_labels      3
# dtype: int64
#
# --->Nan values of each column
# date            0
# title           0
# description     0
# stock_group     0
# combine         0
# full_labels     0
# title_labels    0
# dtype: int64
#
# --> Looking into full_labels
# 2    1518
# 3     203
# 1      60
# Name: full_labels, dtype: int64
# 2    1518
# 3     203
# 1      60
# Name: title_labels, dtype: int64

# %%
b = 1
# Out:
# 2    1423
# 3     300
# 1      58
# Name: full_labels, dtype: int64
