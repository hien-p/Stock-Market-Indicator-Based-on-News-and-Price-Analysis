# %%
import json 
import requests
from collections import defaultdict
from datetime import datetime
# Out:
# Running cells with 'Python 3.10.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
api_key = "023de80d70c24555968bfa08759afad9"
url = "https://newsapi.org/v2/everything?q="+"VIB"+"&apiKey="+api_key

# %%
# get requests
response = requests.get(url)

# %%
import requests
import csv
from datetime import datetime
from collections import defaultdict
import pandas as pd

def get_daily_articles(stock_list):
    """
    This function get_daily_articles takes in a list of stock names as its argument stock_list. 
    It uses the News API (url) to fetch articles related to the stocks in stock_list. For each stock name in the stock_list, it sends a request to the News API with the stock name as a query parameter.
    The response from the API is in JSON format, which is converted into a Python dictionary data. The articles from the response are grouped into a default dictionary daily_articles, where the key is the date of publication and the value is a list of articles published on that day.
    The daily_articles dictionary is then converted into a list of dictionaries daily_articles_list, where each element of the list is a dictionary with two keys: 'date' and 'articles'.
    Finally, the information is written to a CSV file daily_articles.csv with the following columns: 'date', 'title', 'description', and 'stock_group', where 'stock_group' is the stock name in uppercase. The writing to the file is done in the append mode ('a') so that the information for multiple stocks can be written to the same file without overwriting the previous information.    
    """
    
    url = 'https://newsapi.org/v2/everything?'
    api_key = "023de80d70c24555968bfa08759afad9"
  
    for stock_name in stock_list:
        parameters = {
            'q': f'vietnam {stock_name}',
            'sort_by': 'relevancy',
            'apiKey': api_key
        }
  
        response = requests.get(url, params=parameters)
  
        data = response.json()
  
        articles = data['articles']
  
        # Group articles by day
        daily_articles = defaultdict(list)
        for article in articles:
            date = datetime.strptime(article['publishedAt'][:10], '%Y-%m-%d').date()
            daily_articles[date].append(article)
  
        # Convert the daily_articles dictionary to a list of dictionaries
        daily_articles_list = [{'date': date, 'articles': articles} for date, articles in daily_articles.items()]
  
        with open('daily_articles.csv', 'a', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=['date', 'title', 'description','stock_group'])
            for day in daily_articles_list:
                date = day['date']
                for article in day['articles']:
                    writer.writerow({
                        'date': str(date),
                        'title': article['title'],
                        'description': article['description'],
                        'stock_group': stock_name.upper()
                    })

# Read the text file into a list
with open('top_stock.txt') as f:
    stocks = f.readlines()

# Clean up the list and extract the name and stock code
stocks = [stock.strip().split(' (') for stock in stocks]
stocks = [(name, stock.replace(')', '')) for name, stock in stocks]

# Create the dataframe
df = pd.DataFrame(stocks, columns=['name', 'stock'])

# Get the list of stock codes
stock_list = df['stock'].tolist()

# Call the function
get_daily_articles(stock_list)

# Show a timestamp to indicate when the code was run
print(f"Code was run at: {datetime.now()}")
# Out:
# はじめしゃちょー、3億円の自宅を親子に盗撮され憤り　「この子、どう育っちゃうんだろう……」
# 2023-01-18T02:55:00Z
# 優里、突然の“おじいちゃん”化にファン衝撃　歌うとバレバレも「全然別人！」「誰が見ても分からない」
# 2023-01-21T07:20:00Z
# Thẻ VIB đón xu hướng mua sắm online
# 2023-01-09T06:00:00Z
# Thẻ đồng thương hiệu đầu tiên hoàn tới 50% khi mua sắm online
# 2023-01-03T01:00:00Z
# VIB tặng nhiều giải thưởng cho khách giao dịch
# 2023-01-16T04:15:00Z
# 元「Juice=Juice」高木紗友希、新曲がドラマEDに抜てきされ喜び　新名義に「知らなかった」と驚く声も
# 2023-01-06T11:43:00Z
# The following VIBs on the host are missing from the image and will be removed from the host during remediation: vmware-fdm
# 2023-01-02T13:28:46Z
# Mua sắm bằng thẻ đồng thương hiệu LazCard được hoàn đến 50%
# 2023-01-12T01:00:00Z
# Người dùng chuộng thanh toán online
# 2023-01-18T03:00:00Z
# Thẻ tín dụng VIB Travel Elite nhiều ưu đãi dịp Tết
# 2023-01-23T01:00:00Z
# Everything to Know About Dior’s Free Birthday Fragrance Gift Set From Sephora
# 2023-01-04T20:41:00Z
# SeABank có tổng giám đốc mới
# 2023-01-03T15:40:12Z
# Pardon My Fro to Debut First Haircare Line at Walmart
# 2023-01-23T13:11:10Z
# Sephora Reveals Highly Anticipated Beauty Insider Birthday Gifts for 2023, Including Dior, Glow Recipe, ILIA, OUAI – and More!
# 2023-01-04T14:11:32Z
# VN-Index tăng gần 40 điểm phiên đầu năm
# 2023-01-03T09:32:27Z
# Il valore della sperimentazione nel videogioco
# 2023-01-20T09:00:13Z
# Cách phân bổ tài chính dịp Tết
# 2023-01-19T11:00:00Z
# Cổ phiếu LienVietPostBank giao dịch thỏa thuận đột biến
# 2023-01-12T09:18:29Z
# Information on the total number of voting rights and shares
# 2023-01-03T17:00:00Z
# Lợi nhuận VIB vượt 10.000 tỷ đồng năm 2022
# 2023-01-18T01:00:00Z
# The global plant phenotyping market is estimated to be valued at USD 238 million in 2022. It is projected to reach USD 437 million by 2027, recording a CAGR of 12.9%
# 2023-01-23T13:55:00Z
# 雷柏V600S双模振动游戏手柄简评：无线加入，畅玩游戏
# 2023-01-18T12:01:04Z
# Scenic Biotech Strengthens Drug Discovery Expertise in Management Team with the Addition of Kristof Van Emelen
# 2023-01-19T10:06:13Z
# Belgische onderzoekers ontrafelen geheim van langzame hersengroei
# 2023-01-26T19:12:00Z
# Belgische onderzoekers ontrafelen geheim van langzame hersengroei
# 2023-01-26T19:25:13Z
# Vietnam International CommercialBank : Thông báo chuyển địa điểm VIB Quận 11
# 2023-01-03T08:28:03Z
# 8 ưu đãi độc quyền mừng Tết duy nhất 5/1 trên Shopee
# 2023-01-05T03:00:00Z
# Biotalys Achieves Significant Progress in Manufacturing Capabilities for Evoca
# 2023-01-26T06:00:00Z
# Vietnam International CommercialBank : Payment instruction for Deposit book having due date during New Year's Day
# 2022-12-30T08:43:13Z
# Vietnam International CommercialBank : Payment instruction for Deposit book having due date during Tet holiday 2023
# 2023-01-13T11:20:08Z
# بعد سلسلة عقوبات ضد السلطة.. الاحتلال يشدد القيود على زيارة نواب الكنيست العرب للأسرى
# 2023-01-08T08:24:56Z
# Vietnam International CommercialBank : Notice of system upgrade on January 1, 2023
# 2022-12-30T13:22:51Z
# Geheim van langzame hersengroei ontrafeld
# 2023-01-26T14:42:13Z
# DIC Asset AG disposes of “Kaufhof Chemnitz” asset and achieves its transaction targets for the 2022 financial year
# 2023-01-04T06:32:02Z
# Sephora announces its much-anticipated 2023 birthday gift offerings
# 2023-01-04T14:00:00Z
# Nieuwe doorbraak in onderzoek naar alzheimer: bloedtest kan ziekte opsporen
# 2022-12-28T19:58:53Z
# Nieuwe doorbraak in onderzoek naar alzheimer: bloedtest kan ziekte opsporen
# 2022-12-28T21:50:12Z
# To hester skadd etter tak raste i bygning
# 2023-01-27T00:19:36Z
# Dic Asset to pay unchanged dividend - decline in profits expected
# 2023-01-26T09:17:03Z
# Afweercellen versterken zichzelf
# 2023-01-10T20:00:00Z
# Cellen bestrijden verlamming
# 2023-01-17T20:00:00Z
# Vacuum Insulated Pipe Market to Reach Value of US$ 2.06 Billion by 2030, And Rise at a CAGR of 7.5%, Contrive Datum Insights
# 2023-01-24T14:49:00Z
# Cổ phiếu ngân hàng bùng nổ
# 2023-01-16T09:06:45Z
# DIC Asset just achieves target for real estate sales in 2022
# 2023-01-04T06:57:02Z
# DIC Asset AG – the best FFO result in 25 years
# 2023-01-25T18:45:02Z
# Chứng khoán 'xanh vỏ, đỏ lòng'
# 2023-01-09T10:12:16Z
# Cổ phiếu LienVietPostBank sang tay thỏa thuận đột biến
# 2023-01-12T09:18:29Z
# Hospitality real estate market size to grow by USD 75.36 billion from 2022 to 2027: A descriptive analysis of customer landscape, vendor assessment, and market dynamics - Technavio
# 2023-01-12T07:00:00Z
# Distinctive phases and variability of vibration-induced postural reactions highlighted by center of pressure analysis
# 2023-01-23T14:00:00Z
# Cổ phiếu thép đồng loạt tăng trần
# 2023-01-17T08:51:56Z
# ExeVir Bio secures EUR 25 million venture debt financing from the European Investment Bank
# 2023-01-09T07:00:00Z
# DIC Asset AG expects funds from operations of EUR 90 to 97 million for 2023 – Management Board decides on dividend proposal in the amount of EUR 0.75 per share
# 2023-01-25T18:44:02Z
# Geheim van langzame hersengroei ontrafeld
# 2023-01-26T14:17:24Z
# „Ich habe mit meiner Mama geweint, mein Vater brachte mich zum Lachen“
# 2023-01-20T18:41:13Z
# Chizou, nouvelle alternative bruxelloise et vegan au fromage : 5 choses à savoir sur cette idée gratinée… au chou-fleur (vidéo)
# 2023-01-18T08:51:05Z
# Molecure Appoints Dr. Samson Fung, Chief Medical Officer to its Management Board as it Continues to Focus on Successfully Progressing its Expanded Clinical Portfolio
# 2023-01-03T16:39:00Z
# Chizou, nouvelle alternative bruxelloise et vegan au fromage : 5 choses à savoir sur cette idée gratinée… au chou-fleur (vidéo)
# 2023-01-28T14:00:00Z
# Biotalys Achieves Significant Progress in Manufacturing Capabilities for Evoca
# 2023-01-26T06:00:00Z
# Biotalys Achieves Significant Progress in Manufacturing Capabilities for Evoca
# 2023-01-26T06:02:10Z
# Proxmox VE vs. VMware ESXi vs. Hyper-V
# 2022-12-29T14:03:30Z
# Robust single-cell matching and multimodal analysis using shared and distinct features
# 2023-01-09T00:00:00Z
# Vijf jonge Vlaamse professoren over hun onderzoek: ‘Eigenlijk ben ik al twaalf jaar ballonnetjes aan het opblazen’
# 2023-01-14T02:00:25Z
# Vacuum Insulated Pipe Market to Reach Value of US$ 2.06 Billion by 2030, And Rise at a CAGR of 7.5%, Contrive Datum Insights
# 2023-01-24T14:49:00Z
# Spelen darmbacterieën rol bij ontstaan van Alzheimer? Onderzoek UGent zal nieuwe inzichten bieden
# 2023-01-09T13:34:49Z
# The UK’s dream of becoming a ‘science superpower’
# 2023-01-06T00:30:00Z
# Molecure Appoints Dr. Samson Fung, Chief Medical Officer to its Management Board as it Continues to Focus on Successfully Progressing its Expanded Clinical Portfolio
# 2023-01-03T16:32:00Z
# SeABank names new CEO - VnExpress International
# 2023-01-04T03:17:56Z
# Stock trading hits 10-session high - VnExpress International
# 2023-01-06T09:51:14Z
# Create Maintenance Request in SAP S/4HANA using SAP Build Apps(aka AppGyver) and Azure Anomaly Detector
# 2023-01-18T07:21:12Z
# Frequency response of cantilevered plates of small aspect ratio immersed in viscous fluids
# 2023-01-19T10:56:46Z
# Frequency response of cantilevered plates of small aspect ratio immersed in viscous fluids
# 2023-01-19T10:56:46Z
# VN-Index continues sideways - VnExpress International
# 2023-01-12T08:32:45Z
# Funcion de las valvulas del motor
# 2023-01-23T00:35:24Z
# Diamond District shop adds Harry Winston to stock list
# 2023-01-27T21:22:58Z
# Her fyrer elever av fyrverkeri inne på skolen
# 2023-01-06T15:54:46Z
# Que son las valvulas de un motor
# 2023-01-22T19:16:46Z
# Hospitality real estate market size to grow by USD 75.36 billion from 2022 to 2027: A descriptive analysis of customer landscape, vendor assessment, and market dynamics - Technavio
# 2023-01-12T07:00:00Z
# Anti-neuraminidase and anti-hemagglutinin immune serum can confer inter-lineage cross protection against recent influenza B
# 2023-01-23T14:00:00Z
# Nhiều hoạt động tương tác và quà tặng tại MoMo Lắc Xì 2023
# 2023-01-12T01:00:00Z
# Comment on Create Maintenance Request in SAP S/4HANA using SAP Build Apps and Azure Anomaly Detector by Shailendra Jain
# 2023-01-18T11:29:40Z
# Tough year expected for banks in 2023
# 2023-01-05T10:56:00Z

# %%
import requests
import requests
import csv
from datetime import datetime
from collections import defaultdict
import pandas as pd
url = 'https://newsapi.org/v2/everything?'
api_key = "023de80d70c24555968bfa08759afad9"



parameters = {
    'q': 'VN-VIB',
    'sortBy': 'relevancy',
    'apiKey': api_key
}


# parameters = {
# 'q': f'vietnam VN-INDEX',
# 'sort_by': 'relevancy',
# 'apiKey': api_key
# }

response = requests.get(url, params=parameters)

data = response.json()
articles = data['articles']

# Group articles by day
daily_articles = defaultdict(list)
for article in articles:
    date = datetime.strptime(article['publishedAt'][:10], '%Y-%m-%d').date()
    daily_articles[date].append(article)

# Convert the daily_articles dictionary to a list of dictionaries
daily_articles_list = [{'date': date, 'articles': articles} for date, articles in daily_articles.items()]

# %%
daily_articles_list
# Out:
# [{'date': datetime.date(2023, 2, 8),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Digi Invoice giúp tối ưu hóa hiệu quả bán hàng',
#     'description': 'Giải pháp thanh toán Digi Invoice do VIB và KiotViet hợp tác cung cấp giúp chủ shop quản lý thanh toán, kiểm soát nguồn tiền, tối ưu hiệu quả bán hàng.',
#     'url': 'https://vnexpress.net/digi-invoice-giup-toi-uu-hoa-hieu-qua-ban-hang-4568149.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/02/08/image003-6325-1675831860.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=Y-6CvBiuxMtuKdZYzNvVOQ',
#     'publishedAt': '2023-02-08T05:30:00Z',
#     'content': 'Gii pháp thanh toán Digi Invoice do VIB và KiotViet hp tác cung cp giúp ch shop qun lý thanh toán, kim soát ngun tin, ti u hiu qu bán hàng.Theo nhiu ch shop, h kinh doanh cá nhân, vn ln nht mà h gp p… [+2430 chars]'}]},
#  {'date': datetime.date(2023, 2, 6),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'VIB duy trì vị thế top đầu trong lĩnh vực thẻ',
#     'description': 'Số lượng thẻ tín dụng của VIB hiện vượt mốc 600.000 thẻ, tăng gần 9 lần so với 90.000 thẻ năm 2019.',
#     'url': 'https://vnexpress.net/vib-duy-tri-vi-the-top-dau-trong-linh-vuc-the-4558504.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/02/05/z4017901122983a00f63e4070eaf65-3709-3113-1675569324.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=cb1Cvdqn8w8tKc0LGuwDhg',
#     'publishedAt': '2023-02-06T01:00:00Z',
#     'content': 'S lng th tín dng ca VIB hin vt mc 600.000 th, tng gn 9 ln so vi 90.000 th nm 2019.Con s chi tiêu ca ngi Vit qua th tín dng VIB tng trng 8,6 ln, t 8.400 t ng mt nm (360 triu USD) vào nm 2018, lên 75.0… [+3771 chars]'}]},
#  {'date': datetime.date(2023, 2, 17),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'MyVIB 2.0 tối ưu tiện ích cho chủ thẻ tín dụng',
#     'description': 'Ngân hàng số MyVIB 2.0 phát triển tiện ích dành riêng cho chủ thẻ tín dụng với công nghệ AR - hiển thị ưu đãi gần nhất, quản lý chi tiêu hiệu quả.',
#     'url': 'https://vnexpress.net/myvib-2-0-toi-uu-tien-ich-cho-chu-the-tin-dung-4571932.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/02/17/image001-8899-1676626534-16766-6599-7956-1676629660.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=hsHvBZeF4p2ZIVyFqXaPXg',
#     'publishedAt': '2023-02-17T11:00:00Z',
#     'content': 'Ngân hàng s MyVIB 2.0 phát trin tin ích dành riêng cho ch th tín dng vi công ngh AR - hin th u ãi gn nht, qun lý chi tiêu hiu qu.Xem u ãi gn nht\r\nu ãi t ngân hàng và i tác vn là li ích hp dn ca nhng … [+2804 chars]'},
#    {'source': {'id': None, 'name': 'Sputniknews.vn'},
#     'author': 'Hoàng Hoa',
#     'title': 'Bảo hiểm khoản vay cần có quy định pháp luật',
#     'description': 'Việc “ép” khách hàng mua bảo hiểm khoản vay trong khi chưa có luật quy định bắt buộc có thể khiến ngân hàng có hành vi đó phải chịu phạt hành chính từ 40 triệu đồng đến 50 triệu đồng nếu khách hàng có đơn thưa kiện họ. Việt Nam cần sửa đổi, bổ sung Luật liên …',
#     'url': 'https://sputniknews.vn/20230217/bao-hiem-khoan-vay-can-co-quy-dinh-phap-luat-21277884.html',
#     'urlToImage': 'https://cdn1.img.sputniknews.vn/images/sharing/article/vie/21277884.jpg?212792501676632567',
#     'publishedAt': '2023-02-17T11:16:06Z',
#     'content': 'https://sputniknews.vn/20230217/bao-hiem-khoan-vay-can-co-quy-dinh-phap-luat-21277884.html\r\nBo him khon vay cn có quy nh pháp lut\r\nBo him khon vay cn có quy nh pháp lut\r\nVic ép khách hàng mua bo him … [+17144 chars]'}]},
#  {'date': datetime.date(2023, 1, 23),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Thẻ tín dụng VIB Travel Elite nhiều ưu đãi dịp Tết',
#     'description': 'Thẻ VIB Travel Elite giúp tích lũy dặm thưởng, đặc quyền phòng chờ thương gia với ưu đãi đến 40%, hoàn 999.000 đồng cho giao dịch sớm nhất mỗi ngày.',
#     'url': 'https://vnexpress.net/the-tin-dung-vib-travel-elite-nhieu-uu-dai-dip-tet-4562380.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/01/20/image001-9489-1674203295.png?w=1200&h=0&q=100&dpr=1&fit=crop&s=p_r1l2C2DJDoVqVPpJLu3w',
#     'publishedAt': '2023-01-23T01:00:00Z',
#     'content': 'Th VIB Travel Elite giúp tích ly dm thng, c quyn phòng ch thng gia vi u ãi n 40%, hoàn 999.000 ng cho giao dch sm nht mi ngày.Ch th VIB Travel Élite còn có c quyn min phí s dng phòng ch thng gia. Phò… [+3283 chars]'}]},
#  {'date': datetime.date(2023, 1, 31),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Thẻ VIB LazCard hoàn đến 50% khi mua sắm',
#     'description': 'Dòng thẻ VIB LazCard ưu đãi lớn, giảm đến 50% và tặng evoucher trong các dịp đặc biệt như ngày 2/2, tối ưu tiện ích cho người dùng.',
#     'url': 'https://vnexpress.net/the-vib-lazcard-hoan-den-50-khi-mua-sam-4562377.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/01/20/image001-2170-1674202100-16742-5423-1487-1674203154.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=OG8hh-dV4Yb7svzI5CUyeA',
#     'publishedAt': '2023-01-31T01:00:00Z',
#     'content': 'Dòng th VIB LazCard u ãi ln, gim n 50% và tng evoucher trong các dp c bit nh ngày 2/2, ti u tin ích cho ngi dùng.T vài nm tr li ây, thng mi in t bùng n và tr thành kênh mua sm c yêu thích vi nhiu ngi… [+2510 chars]'},
#    {'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Chứng khoán đảo chiều cuối phiên',
#     'description': 'VN-Index giữ sắc đỏ trong gần hết phiên giao dịch 31/1 nhưng bất ngờ bật tăng trở lại trong nửa cuối phiên chiều khi dòng tiền đổ mạnh vào thị trường.',
#     'url': 'https://vnexpress.net/chung-khoan-dao-chieu-cuoi-phien-4565211.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/01/31/QUYN8451-1675154594-4886-1675154637.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=_onm-9i7pbtP1SzEFN8D1w',
#     'publishedAt': '2023-01-31T08:48:05Z',
#     'content': 'VN-Index gi sc trong gn ht phiên giao dch 31/1 nhng bt ng bt tng tr li trong na cui phiên chiu khi dòng tin mnh vào th trng.à gim trong phiên u tun khin tâm lý nhà u t tr nên thn trng hn. iu này c ph… [+1521 chars]'}]},
#  {'date': datetime.date(2023, 1, 30),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Cổ phiếu ngân hàng kéo lùi VN-Index',
#     'description': 'Sắc đỏ lan rộng trong nhóm cổ phiếu ngân hàng và "họ" Vingroup tạo sức ép lên thị trường, khiến VN-Index chốt phiên đầu tuần giảm hơn 14 điểm.',
#     'url': 'https://vnexpress.net/co-phieu-ngan-hang-keo-lui-vn-index-4564826.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/01/30/chungkhoan2-1675071234-1353-1675071237.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=H679povUuPpI7FxiZMbVvA',
#     'publishedAt': '2023-01-30T09:42:51Z',
#     'content': 'Sc lan rng trong nhóm c phiu ngân hàng và "h" Vingroup to sc ép lên th trng, khin VN-Index cht phiên u tun gim hn 14 im.Th trng không còn gi c sc xanh sau phiên giao dch tích cc u nm Quý Mão. VN-Inde… [+1641 chars]'}]},
#  {'date': datetime.date(2023, 2, 1),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Chứng khoán bị bán tháo cuối phiên',
#     'description': 'VN-Index đi ngang gần tham chiếu trong phần lớn thời gian giao dịch nhưng bất ngờ lao dốc chỉ trong vài phút nửa cuối phiên chiều 1/2, đóng cửa giảm 35 điểm.',
#     'url': 'https://vnexpress.net/chung-khoan-bi-ban-thao-cuoi-phien-4565639.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/02/01/QUYN8923-1675240243-7376-1675240283.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=HJaNREyR811dWihJ0mld9A',
#     'publishedAt': '2023-02-01T08:41:30Z',
#     'content': 'VN-Index i ngang gn tham chiu trong phn ln thi gian giao dch nhng bt ng lao dc ch trong vài phút na cui phiên chiu 1/2, óng ca gim 35 im. th ca th trng chng khoán phiên hôm nay là mt ng i ngang kéo d… [+1856 chars]'}]},
#  {'date': datetime.date(2023, 2, 9),
#   'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#     'author': 'VnExpress',
#     'title': 'Thêm một năm ngân hàng lãi lớn',
#     'description': 'Năm ngoái, hơn 20 ngân hàng báo lãi kỷ lục 10,4 tỷ USD nhờ tín dụng tăng mạnh và giảm việc trích lập dự phòng rủi ro.',
#     'url': 'https://vnexpress.net/them-mot-nam-ngan-hang-lai-lon-4567878.html',
#     'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/02/09/vpbank-thanhtung7-1675916574-9498-1675916661.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=HIe9kz3Bv2w1RGDz2RZBCg',
#     'publishedAt': '2023-02-09T06:42:16Z',
#     'content': 'Nm ngoái, hn 20 ngân hàng báo lãi k lc 10,4 t USD nh tín dng tng mnh và gim vic trích lp d phòng ri ro.VnExpress thng kê t báo cáo tài chính hp nht nm 2022 ca 26 ngân hàng niêm yt trên sàn chng khoán… [+6980 chars]'}]}]

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='023de80d70c24555968bfa08759afad9')



# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

# /v2/top-headlines/sources
sources = newsapi.get_sources()

# %%
import requests


url = 'https://newsapi.org/v2/everything?'
api_key = "023de80d70c24555968bfa08759afad9"
parameters = {
    'q': 'vietnam vib',
    'sort_by': 'relevancy',
    'apiKey': api_key
}

response = requests.get(url, params=parameters)

data = response.json()

# %%
articles = data['articles']

# Group articles by day
daily_articles = defaultdict(list)
for article in articles:
    date = datetime.strptime(article['publishedAt'][:10], '%Y-%m-%d').date()
    daily_articles[date].append(article)

# Convert the daily_articles dictionary to a list of dictionaries
daily_articles_list = [{'date': date, 'articles': articles} for date, articles in daily_articles.items()]

# %%
import csv

with open('daily_articles.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['date', 'title', 'description'])
    writer.writeheader()
    for day in daily_articles_list:
        date = day['date']
        for article in day['articles']:
            writer.writerow({
                'date': str(date),
                'title': article['title'],
                'description': article['description']
            })

# %%
data
# Out:
# {'status': 'ok',
#  'totalResults': 12,
#  'articles': [{'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'VnExpress',
#    'title': 'Người dùng chuộng thanh toán online',
#    'description': 'Nhiều người chọn mua sắm, thanh toán với thẻ tín dụng VIB để hưởng bộ ba ưu đãi từ sàn thương mại điện tử, gian hàng và nhà băng.',
#    'url': 'https://vnexpress.net/nguoi-dung-chuong-thanh-toan-online-4561392.html',
#    'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/01/18/image002-3433-1674006403-16740-8882-8466-1674007786.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=9Vx4UhPBSMDE8M_hjQt3eQ',
#    'publishedAt': '2023-01-18T03:00:00Z',
#    'content': 'Nhiu ngi chn mua sm, thanh toán vi th tín dng VIB hng b ba u ãi t sàn thng mi in t, gian hàng và nhà bng.Các nhà cung cp sn phm Tt u mnh tay khuyn mi, gim giá 10-20% hoc mua hai tng mt... cnh tranh v… [+1860 chars]'},
#   {'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'VnExpress',
#    'title': 'Thẻ tín dụng VIB Travel Elite nhiều ưu đãi dịp Tết',
#    'description': 'Thẻ VIB Travel Elite giúp tích lũy dặm thưởng, đặc quyền phòng chờ thương gia với ưu đãi đến 40%, hoàn 999.000 đồng cho giao dịch sớm nhất mỗi ngày.',
#    'url': 'https://vnexpress.net/the-tin-dung-vib-travel-elite-nhieu-uu-dai-dip-tet-4562380.html',
#    'urlToImage': 'https://vcdn1-kinhdoanh.vnecdn.net/2023/01/20/image001-9489-1674203295.png?w=1200&h=0&q=100&dpr=1&fit=crop&s=p_r1l2C2DJDoVqVPpJLu3w',
#    'publishedAt': '2023-01-23T01:00:00Z',
#    'content': 'Th VIB Travel Elite giúp tích ly dm thng, c quyn phòng ch thng gia vi u ãi n 40%, hoàn 999.000 ng cho giao dch sm nht mi ngày.Ch th VIB Travel Élite còn có c quyn min phí s dng phòng ch thng gia. Phò… [+3283 chars]'},
#   {'source': {'id': None, 'name': 'Marketscreener.com'},
#    'author': 'MarketScreener',
#    'title': 'Vietnam International CommercialBank : Thông báo chuyển địa điểm VIB Quận 11',
#    'description': '(marketscreener.com) VIB Quan 11 Branch\n Add: Ground floor, 1st, 2nd and 3rd floors of Building No. 349M-351 Lac Long Quan Street, Ward 5, District 11, City. Ho Chi Minh \n Tel: 39749049 \n 24/7 customer service: 1800 8180\n \n \n Attachments\n \n \n Original Link\n \n…',
#    'url': 'https://www.marketscreener.com/quote/stock/VIETNAM-INTERNATIONAL-COM-119082858/news/Vietnam-International-CommercialBank-Thong-b-o-chuy-7875-n-273-7883-a-273-i-7875-m-VIB-Qu-42647512/?utm_medium=RSS&utm_content=20230103',
#    'urlToImage': 'https://www.marketscreener.com/images/twitter_MS_fdblanc.png',
#    'publishedAt': '2023-01-03T08:28:03Z',
#    'content': 'VIB would like to inform you that:\r\nOn 27/12/2022 VIB Quan 11 has been approved by SBV HCM to relocate to address: Ground floor, 1st, 2nd and 3rd floors of Building No. 349M-351 Lac Long Quan Street,… [+590 chars]'},
#   {'source': {'id': None, 'name': 'Marketscreener.com'},
#    'author': 'MarketScreener',
#    'title': "Vietnam International CommercialBank : Payment instruction for Deposit book having due date during New Year's Day",
#    'description': "(marketscreener.com) \n \n Vietnam International Commercial Joint Stock Bank would like to inform you that all Deposit book opened at VIB's Branch/ Transaction Office and has a due date during holiday, from January 01, 2023 to January 02, 2023, will have paymen…",
#    'url': 'https://www.marketscreener.com/quote/stock/VIETNAM-INTERNATIONAL-COM-119082858/news/Vietnam-International-CommercialBank-Payment-instruction-for-Deposit-book-having-due-date-during-N-42636326/?utm_medium=RSS&utm_content=20221230',
#    'urlToImage': 'https://www.marketscreener.com/images/twitter_MS_fdblanc.png',
#    'publishedAt': '2022-12-30T08:43:13Z',
#    'content': "Vietnam International Commercial Joint Stock Bank (VIB) would like to inform you that all Deposit book opened at VIB's Branch/ Transaction Office and has a due date during holiday, from January 01, 2… [+613 chars]"},
#   {'source': {'id': None, 'name': 'Marketscreener.com'},
#    'author': 'MarketScreener',
#    'title': 'Vietnam International CommercialBank : Payment instruction for Deposit book having due date during Tet holiday 2023',
#    'description': "(marketscreener.com) \n \n Vietnam International Commercial Joint Stock Bank would like to inform you that all Deposit book opened at VIB's Branch/ Transaction Office and has a due date during Lunar New Year 2023, from January 20, 2023 to January 26, 2023, will…",
#    'url': 'https://www.marketscreener.com/quote/stock/VIETNAM-INTERNATIONAL-COM-119082858/news/Vietnam-International-CommercialBank-Payment-instruction-for-Deposit-book-having-due-date-during-T-42726699/?utm_medium=RSS&utm_content=20230113',
#    'urlToImage': 'https://www.marketscreener.com/images/twitter_MS_fdblanc.png',
#    'publishedAt': '2023-01-13T11:20:08Z',
#    'content': "Vietnam International Commercial Joint Stock Bank (VIB) would like to inform you that all Deposit book opened at VIB's Branch/ Transaction Office and has a due date during Lunar New Year 2023, from J… [+623 chars]"},
#   {'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'VnExpress',
#    'title': '8 ưu đãi độc quyền mừng Tết duy nhất 5/1 trên Shopee',
#    'description': 'Shopee gửi lời chúc “phát tài, phát lộc” đến người dùng trong năm 2023 bằng chương trình “5.1 Tết Sale” với 8 ưu đãi độc quyền, duy nhất hôm nay.',
#    'url': 'https://vnexpress.net/8-uu-dai-doc-quyen-mung-tet-duy-nhat-5-1-tren-shopee-4556383.html',
#    'urlToImage': 'https://vcdn1-giadinh.vnecdn.net/2023/01/05/pictu35re1-1672884218-2024-1672884238.png?w=1200&h=0&q=100&dpr=1&fit=crop&s=7Pqwo-jNhg3k8zAsXw6xqA',
#    'publishedAt': '2023-01-05T03:00:00Z',
#    'content': 'Shopee gi li chúc phát tài, phát lc n ngi dùng trong nm 2023 bng chng trình 5.1 Tt Sale vi 8 u ãi c quyn, duy nht hôm nay.Min phí vn chuyn n 70.000 ng\r\nChng trình "5.1 Tt Sale" không ch mang n các sn… [+3101 chars]'},
#   {'source': {'id': None, 'name': 'Marketscreener.com'},
#    'author': 'MarketScreener',
#    'title': 'Vietnam International CommercialBank : Notice of system upgrade on January 1, 2023',
#    'description': '(marketscreener.com) \n \n With the purpose to bring better services, VIB will perform a scheduled system upgrade and we would like to keep you informed as follows:\n \n \n Time & date: from 12:30 AM to 01:55 AM, January 1, 2023\n \n \n During this time, all below se…',
#    'url': 'https://www.marketscreener.com/quote/stock/VIETNAM-INTERNATIONAL-COM-119082858/news/Vietnam-International-CommercialBank-Notice-of-system-upgrade-on-January-1-2023-42638140/?utm_medium=RSS&utm_content=20221230',
#    'urlToImage': 'https://www.marketscreener.com/images/twitter_MS_fdblanc.png',
#    'publishedAt': '2022-12-30T13:22:51Z',
#    'content': 'With the purpose to bring better services, VIB will perform a scheduled system upgrade and we would like to keep you informed as follows:\r\nTime &amp; date: from 12:30 AM to 01:55 AM, January 1, 2023\r… [+559 chars]'},
#   {'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'Dat Nguyen',
#    'title': 'SeABank names new CEO - VnExpress International',
#    'description': 'Loic Michel Marc Faussier is the new CEO of SeABank.',
#    'url': 'https://e.vnexpress.net/news/companies/seabank-names-new-ceo-4556040.html',
#    'urlToImage': 'https://vcdn-english.vnecdn.net/2023/01/04/132621672756437-1672801743-167-4714-1515-1672801958_1200x0.jpg',
#    'publishedAt': '2023-01-04T03:17:56Z',
#    'content': "The bank has appointed the Frenchman, who used to be deputy general manager, for a period of two years six months after Le Thuy resigned as CEO in July last year.\r\nFaussier, 50, who has master's degr… [+392 chars]"},
#   {'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'Dat Nguyen',
#    'title': 'Stock trading hits 10-session high - VnExpress International',
#    'description': 'Vietnam’s benchmark VN-Index dropped 0.41% to 1,051.44 points Friday with trading surging to the highest since December 22.',
#    'url': 'https://e.vnexpress.net/news/economy/stock-trading-hits-10-session-high-4553795.html',
#    'urlToImage': 'https://vcdn-english.vnecdn.net/2023/01/06/WEBQuynhTran04-1672993197-3609-1672993202_1200x0.jpg',
#    'publishedAt': '2023-01-06T09:51:14Z',
#    'content': 'The index closed 4.38 points lower after gaining 9.47 points on Thursday.\r\nTrading on the Ho Chi Minh Stock Exchange (HoSE) increased by 30% to VND11.95 trillion ($509.23 million).\r\nThe VN-30 basket,… [+748 chars]'},
#   {'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'Dat Nguyen',
#    'title': 'VN-Index continues sideways - VnExpress International',
#    'description': 'Vietnam’s benchmark VN-Index rose 0.06% to 1,056.39 points Thursday, having gone sideways since January 3.',
#    'url': 'https://e.vnexpress.net/news/economy/vn-index-continues-sideways-4558950.html',
#    'urlToImage': 'https://vcdn-english.vnecdn.net/2023/01/12/WEBQUYN8595-1673511633-2318-1673511685_1200x0.jpg',
#    'publishedAt': '2023-01-12T08:32:45Z',
#    'content': 'The index closed 0.63 points higher after gaining 2.41 points on Wednesday.\r\nTrading on the Ho Chi Minh Stock Exchange (HoSE) fell by 1.65% to VND8.71 trillion ($371.54 million).\r\nThe VN-30 basket, c… [+819 chars]'},
#   {'source': {'id': None, 'name': 'Vnexpress.net'},
#    'author': 'VnExpress',
#    'title': 'Nhiều hoạt động tương tác và quà tặng tại MoMo Lắc Xì 2023',
#    'description': 'Thông qua Lắc Xì 2023 với nhiều quà tặng giá trị, MoMo mong muốn mang Tết đầm ấm, đủ đầy, gắn kết mọi người sau một năm nhiều biến động.',
#    'url': 'https://vnexpress.net/nhieu-hoat-dong-tuong-tac-va-qua-tang-tai-momo-lac-xi-2023-4559015.html',
#    'urlToImage': 'https://vcdn1-giadinh.vnecdn.net/2023/01/11/m1-1673437200-7977-1673437271.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=U38nULrKK48qeOtQ4SUn-g',
#    'publishedAt': '2023-01-12T01:00:00Z',
#    'content': 'Thông qua Lc Xì 2023 vi nhiu quà tng giá tr, MoMo mong mun mang Tt m m, y, gn kt mi ngi sau mt nm nhiu bin ng."Lc Xì 2023 - Hoàng Thng du xuân" c trin khai t nay n 10/2 vi hình nh bàn c t phú cùng li… [+5267 chars]'},
#   {'source': {'id': None, 'name': 'Vietnamplus.vn'},
#    'author': 'VNA',
#    'title': 'Tough year expected for banks in 2023',
#    'description': 'With a dim outlook for the banking industry, most securities firms expect conservative profit growth for banks in 2023.',
#    'url': 'https://en.vietnamplus.vn/tough-year-expected-for-banks-in-2023/246599.vnp',
#    'urlToImage': None,
#    'publishedAt': '2023-01-05T10:56:00Z',
#    'content': 'HCM City (VNS/VNA) - With a dim outlook for the banking\r\nindustry, most securities firms expect conservative profit growth for banks in\r\n2023.Securities firm VNDirect said the State Bank of Vietnam h… [+3029 chars]'}]}

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
sentiment_analyzer = SentimentIntensityAnalyzer()

with open('daily_articles.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['date', 'title', 'description', 'sentiment'])
    writer.writeheader()
    for day in daily_articles_list:
        date = day['date']
        for article in day['articles']:
            sentiment = sentiment_analyzer.polarity_scores(article['description'])['compound']
            if sentiment > 0.05:
                sentiment = 'positive'
            elif sentiment < -0.05:
                sentiment = 'negative'
            else:
                sentiment = 'neutral'
            writer.writerow({
                'date': str(date),
                'title': article['title'],
                'description': article['description'],
                'sentiment': sentiment
            })
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/harry/nltk_data...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = []
for day in daily_articles_list:
    date = day['date']
    positive_count = 0
    negative_count = 0
    neutral_count = 0
    for article in day['articles']:
        sentiment = sentiment_analyzer.polarity_scores(article['description'])['compound']
        if sentiment > 0.05:
            positive_count += 1
        elif sentiment < -0.05:
            negative_count += 1
        else:
            neutral_count += 1
    data.append({
        'date': date,
        'positive': positive_count,
        'negative': negative_count,
        'neutral': neutral_count
    })
df = pd.DataFrame(data)
df.set_index('date', inplace=True)
df.plot(kind='line')
plt.show()
